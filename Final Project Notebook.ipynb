# %% [markdown]
# # 1. INTRODUCTION
#
# # 1.1. Background
# In the past decade, the lifestyle of urban people has changed with the trends and habits of drinking coffee. Coffee, which was ancient, is identical to drinks commonly used by older men, now women and men of all ages are accustomed to drinking coffee. And not just enjoying coffee, but many people are looking for a place to drink coffee. The coffee shop has finally become a cool hangout with an internet connection while enjoying a variety of steeping coffee beans. This coffee drinking trend will become a big business opportunity. The business world is starting to work on places that serve specialty coffee. With this trend in Hong Kong, it is possible for a coffee shop to get a good profit. However, getting into the business world is not as easy as one might imagine, especially for Hong Kong, where coffee shop is very common. If you already have the capital to open a coffee shop, then you must have the courage, start designing strategies and seeing the market. If you have long been in love with coffee and a hobby of drinking coffee, it means you can start a business with the right passion. Therefore I try to practice my learning at Coursera to answer relevant questions, namely designing strategies to determine which areas are suitable for opening coffee shops.

# %% [markdown]
# ## 1.2. Problem
# Finding data about the area in Hong Kong is a challenge that must be resolved as Hong Kong does not divide area into neighbourhood like some countries. Therefore, this project will use the list of districts in wikipedia to define the area. The price of renting a place to determine the exact location of a coffee shop is also one of the problems that must be resolved.

# %% [markdown]
# ## 1.3. Interest
# I believe this is a relevant challenge with a valid question for anyone who wants to open a coffee shop and determine the right location. The same methodology can be applied according to demands as applicable. This case also applies to anyone interested in exploring starting or finding new business in any city. Finally, this can also serve as a good practical exercise for developing Data Science skills.

# %% [markdown]
# # 2. Data Acquisition and Cleaning
# ## 2.1. Data Acquisition
# The data acquired for this project is a combination of data from two sources. The first data source of data is scraped from a wikipedia page that contains the list of districts in Hong Kong ---> https://en.wikipedia.org/wiki/Districts_of_Hong_Kong. The following are the columns:
# District : Name of the district
# Region: Name of the region
#
# The Second data source is the list of Longitude & Latitude from website latlong.net, the following are columns:
# District : Name of the district
# Latitude : Latitude of the town
# Longitude : Longitude of the town.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from bs4 import BeautifulSoup

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import requests
website_url = requests.get('https://en.wikipedia.org/wiki/Districts_of_Hong_Kong').text

# %%
soup = BeautifulSoup(website_url,'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Districts of Hong Kong - Wikipedia
#   </title>
#   <script>
#    document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgMonthNamesShort":["","Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"wgRequestId":"XmYaIQpAICEAAIPtNrkAAACK","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Districts_of_Hong_Kong","wgTitle":"Districts of Hong Kong","wgCurRevisionId":943646187,"wgRevisionId":943646187,"wgArticleId":151994,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Webarchive template wayback links","EngvarB from July 2014","Use dmy dates from July 2014","Articles containing Chinese-language text","Pages using deprecated image syntax",
# "Wikipedia articles in need of updating from December 2019","All Wikipedia articles in need of updating","Articles needing additional references from December 2019","All articles needing additional references","All articles with vague or ambiguous time","Vague or ambiguous time from December 2019","Districts of Hong Kong","Lists of country subdivisions","Hong Kong geography-related lists"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Districts_of_Hong_Kong","wgRelevantArticleId":151994,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},
# "wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgWikibaseItemId":"Q50256","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"ready","user.tokens":"loading","ext.cite.styles":"ready","mediawiki.legacy.shared":"ready","mediawiki.legacy.commonPrint":"ready","jquery.tablesorter.styles":"ready","jquery.makeCollapsible.styles":"ready","mediawiki.toc.styles":"ready","skins.vector.styles":"ready","wikibase.client.init":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","ext.scribunto.logs","site","mediawiki.page.startup","skins.vector.js","mediawiki.page.ready","jquery.tablesorter","jquery.makeCollapsible","mediawiki.toc",
# "ext.gadget.ReferenceTooltips","ext.gadget.DRN-wizard","ext.gadget.charinsert","ext.gadget.refToolbar","ext.gadget.extra-toolbar-buttons","ext.gadget.switcher","ext.centralauth.centralautologin","mmv.head","mmv.bootstrap.autostart","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.tokens@tffin",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
# });});
#   </script>
#   <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cext.wikimediaBadges%7Cjquery.makeCollapsible.styles%7Cjquery.tablesorter.styles%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.toc.styles%7Cskins.vector.styles%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector">
#   </script>
#   <meta content="" name="ResourceLoaderDynamicStyles"/>
#   <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#   <meta content="MediaWiki 1.35.0-wmf.22" name="generator"/>
#   <meta content="origin" name="referrer"/>
#   <meta content="origin-when-crossorigin" name="referrer"/>
#   <meta content="origin-when-cross-origin" name="referrer"/>
#   <meta content="https://upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Map_of_Hong_Kong_18_Districts_en.svg/1200px-Map_of_Hong_Kong_18_Districts_en.svg.png" property="og:image"/>
#   <link href="/w/index.php?title=Districts_of_Hong_Kong&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#   <link href="/w/index.php?title=Districts_of_Hong_Kong&amp;action=edit" rel="edit" title="Edit this page"/>
#   <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#   <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#   <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#   <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#   <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#   <link href="/w/index.php?title=Special:RecentChanges&amp;feed=atom" rel="alternate" title="Wikipedia Atom feed" type="application/atom+xml"/>
#   <link href="https://en.wikipedia.org/wiki/Districts_of_Hong_Kong" rel="canonical"/>
#   <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#   <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#   <!--[if lt IE 9]><script src="/w/resources/lib/html5shiv/html5shiv.js"></script><![endif]-->
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Districts_of_Hong_Kong rootpage-Districts_of_Hong_Kong skin-vector action-view">
#   <div class="noprint" id="mw-page-base">
#   </div>
#   <div class="noprint" id="mw-head-base">
#   </div>
#   <div class="mw-body" id="content" role="main">
#    <a id="top">
#    </a>
#    <div class="mw-body-content" id="siteNotice">
#     <!-- CentralNotice -->
#    </div>
#    <div class="mw-indicators mw-body-content">
#    </div>
#    <h1 class="firstHeading" id="firstHeading" lang="en">
#     Districts of Hong Kong
#    </h1>
#    <div class="mw-body-content" id="bodyContent">
#     <div class="noprint" id="siteSub">
#      From Wikipedia, the free encyclopedia
#     </div>
#     <div id="contentSub">
#     </div>
#     <div id="jump-to-nav">
#     </div>
#     <a class="mw-jump-link" href="#mw-head">
#      Jump to navigation
#     </a>
#     <a class="mw-jump-link" href="#p-search">
#      Jump to search
#     </a>
#     <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en">
#      <div class="mw-parser-output">
#       <p class="mw-empty-elt">
#       </p>
#       <table class="infobox vevent" style="width:22em;float: right; width: 250px; font-size: 90%; text-align: left; border-spacing: 3px;">
#        <tbody>
#         <tr>
#          <th class="summary" colspan="2" style="text-align:center;font-size:125%;font-weight:bold;font-size: 130%; background-color: #F0F0F0; vertical-align: middle">
#           Districts of Hong Kong
#           <br/>
#           <style data-mw-deduplicate="TemplateStyles:r886047488">
#            .mw-parser-output .nobold{font-weight:normal}
#           </style>
#           <span class="nobold">
#            <span lang="zh-Hant" title="Chinese language text">
#             香港地區
#            </span>
#           </span>
#          </th>
#         </tr>
#         <tr>
#          <td colspan="2" style="text-align:center">
#           <a class="image" href="/wiki/File:Map_of_Hong_Kong_18_Districts_en.svg">
#            <img alt="Map of Hong Kong 18 Districts en.svg" data-file-height="1083" data-file-width="1454" decoding="async" height="186" src="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Map_of_Hong_Kong_18_Districts_en.svg/250px-Map_of_Hong_Kong_18_Districts_en.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Map_of_Hong_Kong_18_Districts_en.svg/375px-Map_of_Hong_Kong_18_Districts_en.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/f/fe/Map_of_Hong_Kong_18_Districts_en.svg/500px-Map_of_Hong_Kong_18_Districts_en.svg.png 2x" width="250"/>
#           </a>
#           <div style="font-size: 85%;">
#            <div>
#             <table class="multicol" role="presentation" style="border-collapse: collapse; padding: 0; border: 0; background:transparent; width:100%;">
#              <tbody>
#               <tr>
#                <td style="text-align: left; vertical-align: top;">
#                 <p>
#                  1.
#                  <a class="mw-redirect" href="/wiki/Islands_District,_Hong_Kong" title="Islands District, Hong Kong">
#                   Islands
#                  </a>
#                  <br/>
#                  2.
#                  <a href="/wiki/Kwai_Tsing_District" title="Kwai Tsing District">
#                   Kwai Tsing
#                  </a>
#                  <br/>
#                  3.
#                  <a class="mw-redirect" href="/wiki/North_District,_Hong_Kong" title="North District, Hong Kong">
#                   North
#                  </a>
#                  <br/>
#                  4.
#                  <a href="/wiki/Sai_Kung_District" title="Sai Kung District">
#                   Sai Kung
#                  </a>
#                  <br/>
#                  5.
#                  <a href="/wiki/Sha_Tin_District" title="Sha Tin District">
#                   Sha Tin
#                  </a>
#                  <br/>
#                  6.
#                  <a href="/wiki/Tai_Po_District" title="Tai Po District">
#                   Tai Po
#                  </a>
#                  <br/>
#                  7.
#                  <a href="/wiki/Tsuen_Wan_District" title="Tsuen Wan District">
#                   Tsuen Wan
#                  </a>
#                  <br/>
#                  8.
#                  <a href="/wiki/Tuen_Mun_District" title="Tuen Mun District">
#                   Tuen Mun
#                  </a>
#                  <br/>
#                  9.
#                  <a href="/wiki/Yuen_Long_District" title="Yuen Long District">
#                   Yuen Long
#                  </a>
#                  <br/>
#                  10.
#                  <a href="/wiki/Kowloon_City_District" title="Kowloon City District">
#                   Kowloon City
#                  </a>
#                  <br/>
#                  11.
#                  <a href="/wiki/Kwun_Tong_District" title="Kwun Tong District">
#                   Kwun Tong
#                  </a>
#                  <br/>
#                  12.
#                  <a href="/wiki/Sham_Shui_Po_District" title="Sham Shui Po District">
#                   Sham Shui Po
#                  </a>
#                  <br/>
#                  13.
#                  <a href="/wiki/Wong_Tai_Sin_District" title="Wong Tai Sin District">
#                   Wong Tai Sin
#                  </a>
#                  <br/>
#                  14.
#                  <a href="/wiki/Yau_Tsim_Mong_District" title="Yau Tsim Mong District">
#                   Yau Tsim Mong
#                  </a>
#                  <br/>
#                  15.
#                  <a href="/wiki/Central_and_Western_District" title="Central and Western District">
#                   Central &amp; Western
#                  </a>
#                  <br/>
#                  16.
#                  <a class="mw-redirect" href="/wiki/Eastern_District,_Hong_Kong" title="Eastern District, Hong Kong">
#                   Eastern
#                  </a>
#                  <br/>
#                  17.
#                  <a class="mw-redirect" href="/wiki/Southern_District,_Hong_Kong" title="Southern District, Hong Kong">
#                   Southern
#                  </a>
#                  <br/>
#                  18.
#                  <a href="/wiki/Wan_Chai_District" title="Wan Chai District">
#                   Wan Chai
#                  </a>
#                 </p>
#                </td>
#               </tr>
#              </tbody>
#             </table>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Category
#          </th>
#          <td style="line-height:1.3em;">
#           <a class="mw-redirect" href="/wiki/Unitary_State" title="Unitary State">
#            Unitary unit
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Location
#          </th>
#          <td style="line-height:1.3em;">
#           <span class="flagicon">
#            <img alt="" class="thumbborder" data-file-height="600" data-file-width="900" decoding="async" height="15" src="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Flag_of_Hong_Kong.svg/23px-Flag_of_Hong_Kong.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Flag_of_Hong_Kong.svg/35px-Flag_of_Hong_Kong.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/5/5b/Flag_of_Hong_Kong.svg/45px-Flag_of_Hong_Kong.svg.png 2x" width="23"/>
#           </span>
#           <a href="/wiki/Hong_Kong" title="Hong Kong">
#            Hong Kong
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Number
#          </th>
#          <td style="line-height:1.3em;">
#           18 districts
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Populations
#          </th>
#          <td style="line-height:1.3em;">
#           137,122 (
#           <a class="mw-redirect" href="/wiki/Islands_District,_Hong_Kong" title="Islands District, Hong Kong">
#            Islands
#           </a>
#           ) – 607,544  (
#           <a href="/wiki/Sha_Tin_District" title="Sha Tin District">
#            Sha Tin
#           </a>
#           )
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Areas
#          </th>
#          <td style="line-height:1.3em;">
#           10 km
#           <sup>
#            2
#           </sup>
#           (4 sq mi) (
#           <a href="/wiki/Yau_Tsim_Mong_District" title="Yau Tsim Mong District">
#            Yau Tsim Mong
#           </a>
#           ) – 220 km
#           <sup>
#            2
#           </sup>
#           (84 sq mi) (
#           <a class="mw-redirect" href="/wiki/North_District,_Hong_Kong" title="North District, Hong Kong">
#            North
#           </a>
#           )
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Government
#          </th>
#          <td style="line-height:1.3em;">
#           <a class="mw-redirect" href="/wiki/District_Councils_of_Hong_Kong" title="District Councils of Hong Kong">
#            District Councils
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <th scope="row" style="white-space:nowrap;padding-right:0.65em;">
#           Subdivisions
#          </th>
#          <td style="line-height:1.3em;">
#           <a href="/wiki/List_of_constituencies_of_Hong_Kong#District_councils_/_district_boards" title="List of constituencies of Hong Kong">
#            Constituency
#           </a>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <table class="vertical-navbox vcard" style="float:right;clear:right;width:22.0em;margin:0 0 1.0em 1.0em;background:#f9f9f9;border:1px solid #aaa;padding:0.2em;border-spacing:0.4em 0;text-align:center;line-height:1.4em;font-size:88%;border-collapse:collapse; background:white; border:1px solid #8C0046;">
#        <tbody>
#         <tr>
#          <td style="padding:0.4em 0;border-bottom:1px solid #8C0046; background:#A20051">
#           <a class="image" href="/wiki/File:Hkpol2.png">
#            <img alt="Hkpol2.png" data-file-height="200" data-file-width="500" decoding="async" height="68" src="//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Hkpol2.png/170px-Hkpol2.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Hkpol2.png/255px-Hkpol2.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/c/cb/Hkpol2.png/340px-Hkpol2.png 2x" width="170"/>
#           </a>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0.3em 0.4em 0.3em;font-weight:bold;border-top: 1px solid #aaa; border-bottom: 1px solid #aaa;background:#C40062; color:white; border-bottom:1px solid #8C0046;">
#           <a href="/wiki/Politics_of_Hong_Kong" title="Politics of Hong Kong">
#            <span style="color:#b0b0b8">
#             Politics
#            </span>
#           </a>
#           and
#           <a href="/wiki/Government_of_Hong_Kong" title="Government of Hong Kong">
#            <span style="color:#b0b0b8">
#             government
#            </span>
#           </a>
#           <br/>
#           of
#           <span class="region">
#            Hong Kong
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:transparent;border-top:1px solid #8C0046;text-align:center;">
#             <a href="/wiki/Law_of_Hong_Kong" title="Law of Hong Kong">
#              Laws
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center;text-align:left;">
#             <ul>
#              <li>
#               <a class="mw-redirect" href="/wiki/Basic_Law_of_Hong_Kong" title="Basic Law of Hong Kong">
#                Basic Law
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/Hong_Kong_Basic_Law_Drafting_Committee" title="Hong Kong Basic Law Drafting Committee">
#                  Drafting Committee
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Hong_Kong_Basic_Law_Consultative_Committee" title="Hong Kong Basic Law Consultative Committee">
#                  Consultative Committee
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Hong_Kong_Basic_Law_Article_23" title="Hong Kong Basic Law Article 23">
#                  Article 23
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/One_country,_two_systems" title="One country, two systems">
#                  One country, two systems
#                 </a>
#                </li>
#                <li>
#                 <a class="mw-redirect" href="/wiki/Sino%E2%80%93British_Joint_Declaration" title="Sino–British Joint Declaration">
#                  Sino–British Joint Declaration
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#             <ul>
#              <li>
#               <a href="/wiki/Hong_Kong_criminal_law" title="Hong Kong criminal law">
#                Criminal law
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/Capital_punishment_in_Hong_Kong" title="Capital punishment in Hong Kong">
#                  Capital punishment in Hong Kong
#                 </a>
#                </li>
#                <li>
#                 <a class="mw-redirect" href="/wiki/Criminal_Procedure_(Hong_Kong)" title="Criminal Procedure (Hong Kong)">
#                  Criminal procedure
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#             <ul>
#              <li>
#               <a href="/wiki/Jury_system_in_Hong_Kong" title="Jury system in Hong Kong">
#                Jury system
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Law_enforcement_in_Hong_Kong" title="Law enforcement in Hong Kong">
#                Law enforcement in Hong Kong
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Human_rights_in_Hong_Kong" title="Human rights in Hong Kong">
#                Human rights
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/LGBT_rights_in_Hong_Kong" title="LGBT rights in Hong Kong">
#                  LGBT rights in Hong Kong
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Internet_censorship_in_Hong_Kong" title="Internet censorship in Hong Kong">
#                  Internet censorship in Hong Kong
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:transparent;border-top:1px solid #8C0046;text-align:center;">
#             <a href="/wiki/Government_of_Hong_Kong" title="Government of Hong Kong">
#              Executive
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center;text-align:left;">
#             <ul>
#              <li>
#               <a href="/wiki/Chief_Executive_of_Hong_Kong" title="Chief Executive of Hong Kong">
#                Chief Executive
#               </a>
#               :
#               <a href="/wiki/Carrie_Lam" title="Carrie Lam">
#                Carrie Lam
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Principal_officials_of_Hong_Kong" title="Principal officials of Hong Kong">
#                Principal officials
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/Chief_Secretary_for_Administration" title="Chief Secretary for Administration">
#                  Chief Secretary
#                 </a>
#                 :
#                 <a href="/wiki/Matthew_Cheung" title="Matthew Cheung">
#                  Matthew Cheung
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Financial_Secretary_(Hong_Kong)" title="Financial Secretary (Hong Kong)">
#                  Financial Secretary
#                 </a>
#                 :
#                 <a href="/wiki/Paul_Chan_Mo-po" title="Paul Chan Mo-po">
#                  Paul Chan
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Secretary_for_Justice_(Hong_Kong)" title="Secretary for Justice (Hong Kong)">
#                  Secretary for Justice
#                 </a>
#                 :
#                 <a href="/wiki/Teresa_Cheng_(politician)" title="Teresa Cheng (politician)">
#                  Teresa Cheng
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#             <ul>
#              <li>
#               <a href="/wiki/Executive_Council_of_Hong_Kong" title="Executive Council of Hong Kong">
#                Executive Council
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 Convenor:
#                 <a href="/wiki/Bernard_Charnwut_Chan" title="Bernard Charnwut Chan">
#                  Bernard Chan
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#             <ul>
#              <li>
#               <a href="/wiki/List_of_Hong_Kong_government_agencies" title="List of Hong Kong government agencies">
#                Government agencies
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/Civil_Service_Bureau" title="Civil Service Bureau">
#                  Civil Service Bureau
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Constitutional_and_Mainland_Affairs_Bureau" title="Constitutional and Mainland Affairs Bureau">
#                  Constitutional and Mainland Affairs Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Electoral_Affairs_Commission" title="Electoral Affairs Commission">
#                    Electoral Affairs Commission
#                   </a>
#                  </li>
#                 </ul>
#                 <dl>
#                  <dd>
#                   <ul>
#                    <li>
#                     <a class="new" href="/w/index.php?title=Electoral_Registration_Office&amp;action=edit&amp;redlink=1" title="Electoral Registration Office (page does not exist)">
#                      Electoral Registration Office
#                     </a>
#                    </li>
#                   </ul>
#                  </dd>
#                 </dl>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Education_Bureau" title="Education Bureau">
#                  Education Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/University_Grants_Committee_(Hong_Kong)" title="University Grants Committee (Hong Kong)">
#                    University Grants Committee
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Environment_Bureau" title="Environment Bureau">
#                  Environment Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Environmental_Protection_Department" title="Environmental Protection Department">
#                    Environmental Protection Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Food_and_Health_Bureau" title="Food and Health Bureau">
#                  Food and Health Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Department_of_Health_(Hong_Kong)" title="Department of Health (Hong Kong)">
#                    Department of Health
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Food_and_Environmental_Hygiene_Department" title="Food and Environmental Hygiene Department">
#                    Food and Environmental Hygiene Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Agriculture,_Fisheries_and_Conservation_Department" title="Agriculture, Fisheries and Conservation Department">
#                    Agriculture, Fisheries and Conservation Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Home_Affairs_Bureau" title="Home Affairs Bureau">
#                  Home Affairs Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Home_Affairs_Department" title="Home Affairs Department">
#                    Home Affairs Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Information_Services_Department" title="Information Services Department">
#                    Information Services Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Leisure_and_Cultural_Services_Department" title="Leisure and Cultural Services Department">
#                    Leisure and Cultural Services Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Labour_and_Welfare_Bureau" title="Labour and Welfare Bureau">
#                  Labour and Welfare Bureau
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Security_Bureau_(Hong_Kong)" title="Security Bureau (Hong Kong)">
#                  Security Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Hong_Kong_Police_Force" title="Hong Kong Police Force">
#                    Hong Kong Police Force
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Hong_Kong_Fire_Services_Department" title="Hong Kong Fire Services Department">
#                    Hong Kong Fire Services Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Hong_Kong_Correctional_Services" title="Hong Kong Correctional Services">
#                    Hong Kong Correctional Services
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Customs_and_Excise_Department_(Hong_Kong)" title="Customs and Excise Department (Hong Kong)">
#                    Customs and Excise Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Immigration_Department_(Hong_Kong)" title="Immigration Department (Hong Kong)">
#                    Immigration Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Government_Flying_Service" title="Government Flying Service">
#                    Government Flying Service
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Civil_Aid_Service" title="Civil Aid Service">
#                    Civil Aid Service
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Auxiliary_Medical_Service" title="Auxiliary Medical Service">
#                    Auxiliary Medical Service
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Transport_and_Housing_Bureau" title="Transport and Housing Bureau">
#                  Transport and Housing Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Housing_Department" title="Housing Department">
#                    Housing Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Commerce_and_Economic_Development_Bureau" title="Commerce and Economic Development Bureau">
#                  Commerce and Economic Development Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Trade_and_Industry_Department" title="Trade and Industry Department">
#                    Trade and Industry Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Hong_Kong_Observatory" title="Hong Kong Observatory">
#                    Hong Kong Observatory
#                   </a>
#                  </li>
#                  <li>
#                   <a class="mw-redirect" href="/wiki/Invest_Hong_Kong" title="Invest Hong Kong">
#                    Invest Hong Kong
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Hongkong_Post" title="Hongkong Post">
#                    Post Office
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/RTHK" title="RTHK">
#                    Radio Television Hong Kong
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Office_of_the_Communications_Authority" title="Office of the Communications Authority">
#                    Office of the Communications Authority
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Development_Bureau" title="Development Bureau">
#                  Development Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Buildings_Department" title="Buildings Department">
#                    Buildings Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Lands_Department" title="Lands Department">
#                    Lands Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Land_Registry_(Hong_Kong)" title="Land Registry (Hong Kong)">
#                    Land Registry
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Architectural_Services_Department" title="Architectural Services Department">
#                    Architectural Services Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Civil_Engineering_and_Development_Department" title="Civil Engineering and Development Department">
#                    Civil Engineering and Development Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Drainage_Services_Department" title="Drainage Services Department">
#                    Drainage Services Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Electrical_and_Mechanical_Services_Department" title="Electrical and Mechanical Services Department">
#                    Electrical and Mechanical Services Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Water_Supplies_Department" title="Water Supplies Department">
#                    Water Supplies Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#               <ul>
#                <li>
#                 <a href="/wiki/Financial_Services_and_the_Treasury_Bureau" title="Financial Services and the Treasury Bureau">
#                  Financial Services and the Treasury Bureau
#                 </a>
#                </li>
#               </ul>
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Census_and_Statistics_Department_(Hong_Kong)" title="Census and Statistics Department (Hong Kong)">
#                    Census and Statistics Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Companies_Registry_(Hong_Kong)" title="Companies Registry (Hong Kong)">
#                    Companies Registry
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Government_Logistics_Department" title="Government Logistics Department">
#                    Government Logistics Department
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Government_Property_Agency" title="Government Property Agency">
#                    Government Property Agency
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Inland_Revenue_Department_(Hong_Kong)" title="Inland Revenue Department (Hong Kong)">
#                    Inland Revenue Department
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#              </dd>
#             </dl>
#             <ul>
#              <li>
#               <a href="/wiki/Hong_Kong_Civil_Service" title="Hong Kong Civil Service">
#                Hong Kong Civil Service
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/Political_Appointments_System" title="Political Appointments System">
#                  Political Appointments System
#                 </a>
#                </li>
#               </ul>
#              </dd>
#             </dl>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:transparent;border-top:1px solid #8C0046;text-align:center;">
#             Legislature
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center;text-align:left;">
#             <ul>
#              <li>
#               <a href="/wiki/Legislative_Council_of_Hong_Kong" title="Legislative Council of Hong Kong">
#                Legislative Council
#               </a>
#              </li>
#             </ul>
#             <dl>
#              <dd>
#               <ul>
#                <li>
#                 <a href="/wiki/President_of_the_Legislative_Council_of_Hong_Kong" title="President of the Legislative Council of Hong Kong">
#                  President
#                 </a>
#                 :
#                 <a href="/wiki/Andrew_Leung" title="Andrew Leung">
#                  Andrew Leung
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/List_of_Members_of_the_Legislative_Council_of_Hong_Kong" title="List of Members of the Legislative Council of Hong Kong">
#                  List of Members of the Legislative Council
#                 </a>
#                </li>
#               </ul>
#              </dd>
#              <dd>
#               Political camps:
#               <dl>
#                <dd>
#                 <ul>
#                  <li>
#                   <a href="/wiki/Pro-Beijing_camp_(Hong_Kong)" title="Pro-Beijing camp (Hong Kong)">
#                    Pro-Beijing camp
#                   </a>
#                  </li>
#                  <li>
#                   <a href="/wiki/Pro-democracy_camp_(Hong_Kong)" title="Pro-democracy camp (Hong Kong)">
#                    Pro-democracy camp
#                   </a>
#                  </li>
#                 </ul>
#                </dd>
#               </dl>
#              </dd>
#             </dl>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:transparent;border-top:1px solid #8C0046;text-align:center;">
#             <a href="/wiki/Judiciary_of_Hong_Kong" title="Judiciary of Hong Kong">
#              Judiciary
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center;text-align:left;">
#             <a href="/wiki/Court_of_Final_Appeal_(Hong_Kong)" title="Court of Final Appeal (Hong Kong)">
#              Court of Final Appeal
#             </a>
#             <ul>
#              <li>
#               <a href="/wiki/Chief_Justice_of_the_Court_of_Final_Appeal" title="Chief Justice of the Court of Final Appeal">
#                Chief Justice
#               </a>
#               :
#               <a href="/wiki/Geoffrey_Ma" title="Geoffrey Ma">
#                Geoffrey Ma
#               </a>
#              </li>
#             </ul>
#             <p>
#              <a href="/wiki/High_Court_(Hong_Kong)" title="High Court (Hong Kong)">
#               High Court
#              </a>
#             </p>
#             <ul>
#              <li>
#               <a href="/wiki/Chief_Judge_of_the_High_Court_of_Hong_Kong" title="Chief Judge of the High Court of Hong Kong">
#                Chief Judge
#               </a>
#               :
#               <a class="mw-redirect" href="/wiki/Jeremy_Poon_Shiu-chor" title="Jeremy Poon Shiu-chor">
#                Jeremy Poon
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Court_of_Appeal_(Hong_Kong)" title="Court of Appeal (Hong Kong)">
#                Court of Appeal
#               </a>
#               <ul>
#                <li>
#                 <a class="new" href="/w/index.php?title=President_of_the_Court_of_Appeal_(Hong_Kong)&amp;action=edit&amp;redlink=1" title="President of the Court of Appeal (Hong Kong) (page does not exist)">
#                  President of the Court of Appeal
#                 </a>
#                </li>
#               </ul>
#              </li>
#              <li>
#               <a href="/wiki/Court_of_First_Instance_(Hong_Kong)" title="Court of First Instance (Hong Kong)">
#                Court of First Instance
#               </a>
#              </li>
#             </ul>
#             <p>
#              <a href="/wiki/District_Court_(Hong_Kong)" title="District Court (Hong Kong)">
#               District Court
#              </a>
#             </p>
#             <ul>
#              <li>
#               <a class="new" href="/w/index.php?title=Chief_District_Judge_(Hong_Kong)&amp;action=edit&amp;redlink=1" title="Chief District Judge (Hong Kong) (page does not exist)">
#                Chief District Judge
#               </a>
#               : Justin Ko
#              </li>
#             </ul>
#             <p>
#              <a href="/wiki/Magistrates%27_Court_(Hong_Kong)" title="Magistrates' Court (Hong Kong)">
#               Magistrates' Court
#              </a>
#             </p>
#             <ul>
#              <li>
#               <a class="new" href="/w/index.php?title=Chief_Magistrate_(Hong_Kong)&amp;action=edit&amp;redlink=1" title="Chief Magistrate (Hong Kong) (page does not exist)">
#                Chief Magistrate
#               </a>
#               : So Wai-tak
#              </li>
#             </ul>
#             <p>
#              Special courts and tribunals:
#             </p>
#             <ul>
#              <li>
#               <a href="/wiki/Judiciary_of_Hong_Kong#The_Coroner’s_Court" title="Judiciary of Hong Kong">
#                Coroner’s Court
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Judiciary_of_Hong_Kong#The_Labour_Tribunal" title="Judiciary of Hong Kong">
#                Labour Tribunal
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Lands_Tribunal_(Hong_Kong)" title="Lands Tribunal (Hong Kong)">
#                Lands Tribunal
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Market_Misconduct_Tribunal" title="Market Misconduct Tribunal">
#                Market Misconduct Tribunal
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Judiciary_of_Hong_Kong#The_Obscene_Articles_Tribunal" title="Judiciary of Hong Kong">
#                Obscene Articles Tribunal
#               </a>
#              </li>
#              <li>
#               <a href="/wiki/Judiciary_of_Hong_Kong#The_Small_Claims_Tribunal" title="Judiciary of Hong Kong">
#                Small Claims Tribunal
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </td>
#         </tr>
#         <tr>
#          <td style="padding:0 0.1em 0.4em">
#           <div class="NavFrame collapsed" style="border:none;padding:0">
#            <div class="NavHead" style="font-size:105%;background:transparent;text-align:left;background:transparent;border-top:1px solid #8C0046;text-align:center;">
#             <a class="mw-selflink selflink">
#              Districts
#             </a>
#            </div>
#            <div class="NavContent" style="font-size:105%;padding:0.2em 0 0.4em;text-align:center;text-align:left;">
#             <dl>
#              <dd>
#               <a class="mw-redirect" href="/wiki/District_Councils_of_Hong_Kong" title="District Councils of Hong Kong">
#                District Councils
#               </a>
#               <ul>
#                <li>
#                 <a href="/wiki/Central_and_Western_District" title="Central and Western District">
#                  Central and Western
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Eastern_District_(Hong_Kong)" title="Eastern District (Hong Kong)">
#                  Eastern
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Islands_District" title="Islands District">
#                  Islands
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Kowloon_City_District" title="Kowloon City District">
#                  Kowloon City
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Kwai_Tsing_District" title="Kwai Tsing District">
#                  Kwai Tsing
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Kwun_Tong_District" title="Kwun Tong District">
#                  Kwun Tong
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/North_District_(Hong_Kong)" title="North District (Hong Kong)">
#                  North
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Sai_Kung_District" title="Sai Kung District">
#                  Sai Kung
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Sha_Tin_District" title="Sha Tin District">
#                  Sha Tin
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Sham_Shui_Po_District" title="Sham Shui Po District">
#                  Sham Shui Po
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Southern_District_(Hong_Kong)" title="Southern District (Hong Kong)">
#                  Southern
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Tai_Po_District" title="Tai Po District">
#                  Tai Po
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Tsuen_Wan_District" title="Tsuen Wan District">
#                  Tsuen Wan
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Tuen_Mun_District" title="Tuen Mun District">
#                  Tuen Mun
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Wan_Chai_District" title="Wan Chai District">
#                  Wan Chai
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Wong_Tai_Sin_District" title="Wong Tai Sin District">
#                  Wong Tai Sin
#                 </a>
#                </li>
#                <li>
#                 <a href="/wiki/Yau_Tsim_Mong_District" title="Yau Tsim Mong District">
#                  Yau Tsim Mong
#                 </a>
# ...
#         <a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes in the wiki [r]">
#          Recent changes
#         </a>
#        </li>
#        <li id="n-contactpage">
#         <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia">
#          Contact page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-tb-label" class="portal" id="p-tb" role="navigation">
#      <h3 id="p-tb-label">
#       Tools
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="t-whatlinkshere">
#         <a accesskey="j" href="/wiki/Special:WhatLinksHere/Districts_of_Hong_Kong" title="List of all English Wikipedia pages containing links to this page [j]">
#          What links here
#         </a>
#        </li>
#        <li id="t-recentchangeslinked">
#         <a accesskey="k" href="/wiki/Special:RecentChangesLinked/Districts_of_Hong_Kong" rel="nofollow" title="Recent changes in pages linked from this page [k]">
#          Related changes
#         </a>
#        </li>
#        <li id="t-upload">
#         <a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">
#          Upload file
#         </a>
#        </li>
#        <li id="t-specialpages">
#         <a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">
#          Special pages
#         </a>
#        </li>
#        <li id="t-permalink">
#         <a href="/w/index.php?title=Districts_of_Hong_Kong&amp;oldid=943646187" title="Permanent link to this revision of the page">
#          Permanent link
#         </a>
#        </li>
#        <li id="t-info">
#         <a href="/w/index.php?title=Districts_of_Hong_Kong&amp;action=info" title="More information about this page">
#          Page information
#         </a>
#        </li>
#        <li id="t-wikibase">
#         <a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q50256" title="Link to connected data repository item [g]">
#          Wikidata item
#         </a>
#        </li>
#        <li id="t-cite">
#         <a href="/w/index.php?title=Special:CiteThisPage&amp;page=Districts_of_Hong_Kong&amp;id=943646187" title="Information on how to cite this page">
#          Cite this page
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-wikibase-otherprojects-label" class="portal" id="p-wikibase-otherprojects" role="navigation">
#      <h3 id="p-wikibase-otherprojects-label">
#       In other projects
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="wb-otherproject-link wb-otherproject-commons">
#         <a href="https://commons.wikimedia.org/wiki/Category:Districts_of_Hong_Kong" hreflang="en">
#          Wikimedia Commons
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-coll-print_export-label" class="portal" id="p-coll-print_export" role="navigation">
#      <h3 id="p-coll-print_export-label">
#       Print/export
#      </h3>
#      <div class="body">
#       <ul>
#        <li id="coll-create_a_book">
#         <a href="/w/index.php?title=Special:Book&amp;bookcmd=book_creator&amp;referer=Districts+of+Hong+Kong">
#          Create a book
#         </a>
#        </li>
#        <li id="coll-download-as-rl">
#         <a href="/w/index.php?title=Special:ElectronPdf&amp;page=Districts+of+Hong+Kong&amp;action=show-download-screen">
#          Download as PDF
#         </a>
#        </li>
#        <li id="t-print">
#         <a accesskey="p" href="/w/index.php?title=Districts_of_Hong_Kong&amp;printable=yes" title="Printable version of this page [p]">
#          Printable version
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div aria-labelledby="p-lang-label" class="portal" id="p-lang" role="navigation">
#      <h3 id="p-lang-label">
#       Languages
#      </h3>
#      <div class="body">
#       <ul>
#        <li class="interlanguage-link interwiki-ar">
#         <a class="interlanguage-link-target" href="https://ar.wikipedia.org/wiki/%D9%85%D9%82%D8%A7%D8%B7%D8%B9%D8%A7%D8%AA_%D9%87%D9%88%D9%86%D8%BA_%D9%83%D9%88%D9%86%D8%BA" hreflang="ar" lang="ar" title="مقاطعات هونغ كونغ – Arabic">
#          العربية
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-bar">
#         <a class="interlanguage-link-target" href="https://bar.wikipedia.org/wiki/Distrikte_vo_Hongkong" hreflang="bar" lang="bar" title="Distrikte vo Hongkong – Bavarian">
#          Boarisch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-de">
#         <a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Distrikte_von_Hongkong" hreflang="de" lang="de" title="Distrikte von Hongkong – German">
#          Deutsch
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-eu">
#         <a class="interlanguage-link-target" href="https://eu.wikipedia.org/wiki/Hong_Kongen_banaketa_administratiboa" hreflang="eu" lang="eu" title="Hong Kongen banaketa administratiboa – Basque">
#          Euskara
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-fr">
#         <a class="interlanguage-link-target" href="https://fr.wikipedia.org/wiki/Districts_de_Hong_Kong" hreflang="fr" lang="fr" title="Districts de Hong Kong – French">
#          Français
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ko">
#         <a class="interlanguage-link-target" href="https://ko.wikipedia.org/wiki/%ED%99%8D%EC%BD%A9%EC%9D%98_%ED%96%89%EC%A0%95%EA%B5%AC%EC%97%AD" hreflang="ko" lang="ko" title="홍콩의 행정구역 – Korean">
#          한국어
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-it">
#         <a class="interlanguage-link-target" href="https://it.wikipedia.org/wiki/Distretti_di_Hong_Kong" hreflang="it" lang="it" title="Distretti di Hong Kong – Italian">
#          Italiano
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ms">
#         <a class="interlanguage-link-target" href="https://ms.wikipedia.org/wiki/Daerah-daerah_di_Hong_Kong" hreflang="ms" lang="ms" title="Daerah-daerah di Hong Kong – Malay">
#          Bahasa Melayu
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ja">
#         <a class="interlanguage-link-target" href="https://ja.wikipedia.org/wiki/%E9%A6%99%E6%B8%AF%E3%81%AE%E8%A1%8C%E6%94%BF%E5%8C%BA%E7%94%BB" hreflang="ja" lang="ja" title="香港の行政区画 – Japanese">
#          日本語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-no">
#         <a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Hongkongs_distrikter" hreflang="nb" lang="nb" title="Hongkongs distrikter – Norwegian Bokmål">
#          Norsk bokmål
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pl">
#         <a class="interlanguage-link-target" href="https://pl.wikipedia.org/wiki/Dzielnice_Hongkongu" hreflang="pl" lang="pl" title="Dzielnice Hongkongu – Polish">
#          Polski
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-pt">
#         <a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Distritos_de_Hong_Kong" hreflang="pt" lang="pt" title="Distritos de Hong Kong – Portuguese">
#          Português
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ru">
#         <a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%90%D0%B4%D0%BC%D0%B8%D0%BD%D0%B8%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B8%D0%B2%D0%BD%D0%BE%D0%B5_%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%93%D0%BE%D0%BD%D0%BA%D0%BE%D0%BD%D0%B3%D0%B0" hreflang="ru" lang="ru" title="Административное деление Гонконга – Russian">
#          Русский
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ta">
#         <a class="interlanguage-link-target" href="https://ta.wikipedia.org/wiki/%E0%AE%B9%E0%AF%8A%E0%AE%99%E0%AF%8D%E0%AE%95%E0%AF%8A%E0%AE%99%E0%AF%8D_%E0%AE%AE%E0%AE%BE%E0%AE%B5%E0%AE%9F%E0%AF%8D%E0%AE%9F%E0%AE%99%E0%AF%8D%E0%AE%95%E0%AE%B3%E0%AF%8D" hreflang="ta" lang="ta" title="ஹொங்கொங் மாவட்டங்கள் – Tamil">
#          தமிழ்
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-tr">
#         <a class="interlanguage-link-target" href="https://tr.wikipedia.org/wiki/Hong_Kong%27un_semtleri" hreflang="tr" lang="tr" title="Hong Kong'un semtleri – Turkish">
#          Türkçe
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-uk">
#         <a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%90%D0%B4%D0%BC%D1%96%D0%BD%D1%96%D1%81%D1%82%D1%80%D0%B0%D1%82%D0%B8%D0%B2%D0%BD%D0%B8%D0%B9_%D0%BF%D0%BE%D0%B4%D1%96%D0%BB_%D0%93%D0%BE%D0%BD%D0%BA%D0%BE%D0%BD%D0%B3%D1%83" hreflang="uk" lang="uk" title="Адміністративний поділ Гонконгу – Ukrainian">
#          Українська
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-ur">
#         <a class="interlanguage-link-target" href="https://ur.wikipedia.org/wiki/%DB%81%D8%A7%D9%86%DA%AF_%DA%A9%D8%A7%D9%86%DA%AF_%DA%A9%DB%92_%D8%A7%D8%B6%D9%84%D8%A7%D8%B9" hreflang="ur" lang="ur" title="ہانگ کانگ کے اضلاع – Urdu">
#          اردو
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-vi">
#         <a class="interlanguage-link-target" href="https://vi.wikipedia.org/wiki/Ph%C3%A2n_c%E1%BA%A5p_h%C3%A0nh_ch%C3%ADnh_H%E1%BB%93ng_K%C3%B4ng" hreflang="vi" lang="vi" title="Phân cấp hành chính Hồng Kông – Vietnamese">
#          Tiếng Việt
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-wuu">
#         <a class="interlanguage-link-target" href="https://wuu.wikipedia.org/wiki/%E9%A6%99%E6%B8%AF%E6%94%BF%E5%8C%BA" hreflang="wuu" lang="wuu" title="香港政区 – Wu Chinese">
#          吴语
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh-yue">
#         <a class="interlanguage-link-target" href="https://zh-yue.wikipedia.org/wiki/%E9%A6%99%E6%B8%AF%E6%94%BF%E5%8D%80" hreflang="yue" lang="yue" title="香港政區 – Cantonese">
#          粵語
#         </a>
#        </li>
#        <li class="interlanguage-link interwiki-zh">
#         <a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E9%A6%99%E6%B8%AF%E8%A1%8C%E6%94%BF%E5%8D%80%E5%8A%83" hreflang="zh" lang="zh" title="香港行政區劃 – Chinese">
#          中文
#         </a>
#        </li>
#       </ul>
#       <div class="after-portlet after-portlet-lang">
#        <span class="wb-langlinks-edit wb-langlinks-link">
#         <a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q50256#sitelinks-wikipedia" title="Edit interlanguage links">
#          Edit links
#         </a>
#        </span>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div id="footer" role="contentinfo">
#    <ul class="" id="footer-info">
#     <li id="footer-info-lastmod">
#      This page was last edited on 3 March 2020, at 03:08
#      <span class="anonymous-show">
#       (UTC)
#      </span>
#      .
#     </li>
#     <li id="footer-info-copyright">
#      Text is available under the
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">
#       Creative Commons Attribution-ShareAlike License
#      </a>
#      <a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;">
#      </a>
#      ;
# additional terms may apply.  By using this site, you agree to the
#      <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">
#       Terms of Use
#      </a>
#      and
#      <a href="//foundation.wikimedia.org/wiki/Privacy_policy">
#       Privacy Policy
#      </a>
#      . Wikipedia® is a registered trademark of the
#      <a href="//www.wikimediafoundation.org/">
#       Wikimedia Foundation, Inc.
#      </a>
#      , a non-profit organization.
#     </li>
#    </ul>
#    <ul class="" id="footer-places">
#     <li id="footer-places-privacy">
#      <a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">
#       Privacy policy
#      </a>
#     </li>
#     <li id="footer-places-about">
#      <a href="/wiki/Wikipedia:About" title="Wikipedia:About">
#       About Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-disclaimer">
#      <a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">
#       Disclaimers
#      </a>
#     </li>
#     <li id="footer-places-contact">
#      <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">
#       Contact Wikipedia
#      </a>
#     </li>
#     <li id="footer-places-developers">
#      <a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">
#       Developers
#      </a>
#     </li>
#     <li id="footer-places-statslink">
#      <a href="https://stats.wikimedia.org/#/en.wikipedia.org">
#       Statistics
#      </a>
#     </li>
#     <li id="footer-places-cookiestatement">
#      <a href="https://foundation.wikimedia.org/wiki/Cookie_statement">
#       Cookie statement
#      </a>
#     </li>
#     <li id="footer-places-mobileview">
#      <a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Districts_of_Hong_Kong&amp;mobileaction=toggle_view_mobile">
#       Mobile view
#      </a>
#     </li>
#    </ul>
#    <ul class="noprint" id="footer-icons">
#     <li id="footer-copyrightico">
#      <a href="https://wikimediafoundation.org/">
#       <img alt="Wikimedia Foundation" height="31" src="/static/images/wikimedia-button.png" srcset="/static/images/wikimedia-button-1.5x.png 1.5x, /static/images/wikimedia-button-2x.png 2x" width="88"/>
#      </a>
#     </li>
#     <li id="footer-poweredbyico">
#      <a href="https://www.mediawiki.org/">
#       <img alt="Powered by MediaWiki" height="31" src="/static/images/poweredby_mediawiki_88x31.png" srcset="/static/images/poweredby_mediawiki_132x47.png 1.5x, /static/images/poweredby_mediawiki_176x62.png 2x" width="88"/>
#      </a>
#     </li>
#    </ul>
#    <div style="clear: both;">
#    </div>
#   </div>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.676","walltime":"0.930","ppvisitednodes":{"value":2564,"limit":1000000},"postexpandincludesize":{"value":137744,"limit":2097152},"templateargumentsize":{"value":5553,"limit":2097152},"expansiondepth":{"value":15,"limit":40},"expensivefunctioncount":{"value":7,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":12431,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00%  801.930      1 -total"," 36.43%  292.117      1 Template:Infobox_subdivision_type"," 35.73%  286.537      1 Template:Infobox"," 24.95%  200.065     19 Template:Lang"," 24.15%  193.655      1 Template:Nobold"," 19.53%  156.628      1 Template:Reflist"," 11.21%   89.920      2 Template:Ambox","  9.27%   74.352      3 Template:ISBN","  7.32%   58.676      1 Template:Update-section","  7.11%   57.023      1 Template:Cite_web"]},"scribunto":{"limitreport-timeusage":{"value":"0.344","limit":"10.000"},"limitreport-memusage":{"value":15769971,"limit":52428800},"limitreport-logs":"table#1 {\n  [\"size\"] = \"tiny\",\n}\n"},"cachereport":{"origin":"mw1367","timestamp":"20200308084259","ttl":2592000,"transientcontent":false}}});});
#   </script>
#   <script type="application/ld+json">
#    {"@context":"https:\/\/schema.org","@type":"Article","name":"Districts of Hong Kong","url":"https:\/\/en.wikipedia.org\/wiki\/Districts_of_Hong_Kong","sameAs":"http:\/\/www.wikidata.org\/entity\/Q50256","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q50256","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2002-11-26T16:14:35Z","dateModified":"2020-03-03T03:08:48Z","image":"https:\/\/upload.wikimedia.org\/wikipedia\/commons\/f\/fe\/Map_of_Hong_Kong_18_Districts_en.svg","headline":"People's Republic of China prefecture-level subdivision used in Hong Kong"}
#   </script>
#   <script>
#    (RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":122,"wgHostname":"mw1331"});});
#   </script>
#  </body>
# </html>

# %%
My_table = soup.find('table',{'class':'wikitable sortable'})
My_table
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>District
# </th>
# <th>Chinese
# </th>
# <th>Population<sup class="noprint Inline-Template" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Manual_of_Style/Dates_and_numbers#Chronological_items" title="Wikipedia:Manual of Style/Dates and numbers"><span title="The time period mentioned near this tag is ambiguous. (December 2019)">when?</span></a></i>]</sup> <sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup>
# </th>
# <th>Area<br/>(km²)
# </th>
# <th>Density<br/>(/km²)
# </th>
# <th>Region
# </th></tr>
# <tr>
# <td><a href="/wiki/Central_and_Western_District" title="Central and Western District"><span class="nowrap">Central and Western</span></a></td>
# <td><span lang="zh-HK" title="Chinese language text">中西區</span></td>
# <td align="right">244,600</td>
# <td align="right">12.44</td>
# <td align="right">19,983.92</td>
# <td><span class="nowrap"><a href="/wiki/Hong_Kong_Island" title="Hong Kong Island">Hong Kong Island</a></span>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Eastern_District,_Hong_Kong" title="Eastern District, Hong Kong">Eastern</a></td>
# <td><span lang="zh-HK" title="Chinese language text">東區</span></td>
# <td align="right">574,500</td>
# <td align="right">18.56</td>
# <td align="right">31,217.67</td>
# <td><a href="/wiki/Hong_Kong_Island" title="Hong Kong Island">Hong Kong Island</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Southern_District,_Hong_Kong" title="Southern District, Hong Kong">Southern</a></td>
# <td><span lang="zh-HK" title="Chinese language text">南區</span></td>
# <td align="right">269,200</td>
# <td align="right">38.85</td>
# <td align="right">6,962.68</td>
# <td><a href="/wiki/Hong_Kong_Island" title="Hong Kong Island">Hong Kong Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Wan_Chai_District" title="Wan Chai District">Wan Chai</a></td>
# <td><span lang="zh-HK" title="Chinese language text">灣仔區</span></td>
# <td align="right">150,900</td>
# <td align="right">9.83</td>
# <td align="right">15,300.10</td>
# <td><a href="/wiki/Hong_Kong_Island" title="Hong Kong Island">Hong Kong Island</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Sham_Shui_Po_District" title="Sham Shui Po District">Sham Shui Po</a></td>
# <td><span class="nowrap"><span lang="zh-HK" title="Chinese language text">深水埗區</span></span></td>
# <td align="right">390,600</td>
# <td align="right">9.35</td>
# <td align="right">41,529.41</td>
# <td><a href="/wiki/Kowloon" title="Kowloon">Kowloon</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Kowloon_City_District" title="Kowloon City District">Kowloon City</a></td>
# <td><span lang="zh-HK" title="Chinese language text">九龍城區</span></td>
# <td align="right">405,400</td>
# <td align="right">10.02</td>
# <td align="right">40,194.70</td>
# <td><a href="/wiki/Kowloon" title="Kowloon">Kowloon</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Kwun_Tong_District" title="Kwun Tong District">Kwun Tong</a></td>
# <td><span lang="zh-HK" title="Chinese language text">觀塘區</span></td>
# <td align="right">641,100</td>
# <td align="right">11.27</td>
# <td align="right">56,779.05</td>
# <td><a href="/wiki/Kowloon" title="Kowloon">Kowloon</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Wong_Tai_Sin_District" title="Wong Tai Sin District">Wong Tai Sin</a></td>
# <td><span lang="zh-HK" title="Chinese language text">黃大仙區</span></td>
# <td align="right">426,200</td>
# <td align="right">9.30</td>
# <td align="right">45,645.16</td>
# <td><a href="/wiki/Kowloon" title="Kowloon">Kowloon</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Yau_Tsim_Mong_District" title="Yau Tsim Mong District">Yau Tsim Mong</a></td>
# <td><span lang="zh-HK" title="Chinese language text">油尖旺區</span></td>
# <td align="right">318,100</td>
# <td align="right">6.99</td>
# <td align="right">44,864.09</td>
# <td><a href="/wiki/Kowloon" title="Kowloon">Kowloon</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/Islands_District,_Hong_Kong" title="Islands District, Hong Kong">Islands</a></td>
# <td><span lang="zh-HK" title="Chinese language text">離島區</span></td>
# <td align="right">146,900</td>
# <td align="right">175.12</td>
# <td align="right">825.14</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Kwai_Tsing_District" title="Kwai Tsing District">Kwai Tsing</a></td>
# <td><span lang="zh-HK" title="Chinese language text">葵青區</span></td>
# <td align="right">507,100</td>
# <td align="right">23.34</td>
# <td align="right">21,503.86</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a class="mw-redirect" href="/wiki/North_District,_Hong_Kong" title="North District, Hong Kong">North</a></td>
# <td><span lang="zh-HK" title="Chinese language text">北區</span></td>
# <td align="right">310,800</td>
# <td align="right">136.61</td>
# <td align="right">2,220.19</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Sai_Kung_District" title="Sai Kung District">Sai Kung</a></td>
# <td><span lang="zh-HK" title="Chinese language text">西貢區</span></td>
# <td align="right">448,600</td>
# <td align="right">129.65</td>
# <td align="right">3,460.08</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Sha_Tin_District" title="Sha Tin District">Sha Tin</a></td>
# <td><span lang="zh-HK" title="Chinese language text">沙田區</span></td>
# <td align="right">648,200</td>
# <td align="right">68.71</td>
# <td align="right">9,433.85</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Tai_Po_District" title="Tai Po District">Tai Po</a></td>
# <td><span lang="zh-HK" title="Chinese language text">大埔區</span></td>
# <td align="right">307,100</td>
# <td align="right">136.15</td>
# <td align="right">2,220.35</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Tsuen_Wan_District" title="Tsuen Wan District">Tsuen Wan</a></td>
# <td><span lang="zh-HK" title="Chinese language text">荃灣區</span></td>
# <td align="right">303,600</td>
# <td align="right">61.71</td>
# <td align="right">4,887.38</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Tuen_Mun_District" title="Tuen Mun District">Tuen Mun</a></td>
# <td><span lang="zh-HK" title="Chinese language text">屯門區</span></td>
# <td align="right">495,900</td>
# <td align="right">82.89</td>
# <td align="right">5,889.38</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr>
# <tr>
# <td><a href="/wiki/Yuen_Long_District" title="Yuen Long District">Yuen Long</a></td>
# <td><span lang="zh-HK" title="Chinese language text">元朗區</span></td>
# <td align="right">607,200</td>
# <td align="right">138.46</td>
# <td align="right">4,297.99</td>
# <td><a href="/wiki/New_Territories" title="New Territories">New Territories</a>
# </td></tr></tbody></table>

# %%
Districts = ""
for tr in My_table.find_all('tr'):
    row1 = ""
    for tds in tr.find_all('td'):
        for a in tds.find_all('a'):
            row1 = row1 + "," + tds.text
    Districts = Districts + row1[1:]
print(Districts)
# Out:
# Central and Western,Hong Kong Island
# Eastern,Hong Kong Island
# Southern,Hong Kong Island
# Wan Chai,Hong Kong Island
# Sham Shui Po,Kowloon
# Kowloon City,Kowloon
# Kwun Tong,Kowloon
# Wong Tai Sin,Kowloon
# Yau Tsim Mong,Kowloon
# Islands,New Territories
# Kwai Tsing,New Territories
# North,New Territories
# Sai Kung,New Territories
# Sha Tin,New Territories
# Tai Po,New Territories
# Tsuen Wan,New Territories
# Tuen Mun,New Territories
# Yuen Long,New Territories

# %%
# store the data in a csv file, as all data are seperated by comma
file = open('Hong Kong.csv',"wb")
file.write(bytes(Districts,encoding = "ascii",errors = "ignore"))
# Out:
# 439

# %%
# turn the csv file to dataframe
df = pd.read_csv('Hong Kong.csv',header=None)
df.columns = ['Districts','Regions']
df.head()
# Out:
#              Districts           Regions
# 0  Central and Western  Hong Kong Island
# 1              Eastern  Hong Kong Island
# 2             Southern  Hong Kong Island
# 3             Wan Chai  Hong Kong Island
# 4         Sham Shui Po           Kowloon

# %%
# The code was removed by Watson Studio for sharing.

# %%
from ibm_botocore.client import Config
import ibm_boto3
cos = ibm_boto3.client(service_name='s3',
    ibm_api_key_id=credentials['IBM_API_KEY_ID'],
    ibm_service_instance_id=credentials['IAM_SERVICE_ID'],
    ibm_auth_endpoint=credentials['IBM_AUTH_ENDPOINT'],
    config=Config(signature_version='oauth'),
    endpoint_url=credentials['ENDPOINT'])

# %%
cos.download_file(Bucket=credentials['BUCKET'],Key='Hong_Kong_geo.csv',Filename='Hong_Kong_geo.csv')

# %%
df_geo = pd.read_csv('Hong_Kong_geo.csv')
df_geo.columns=['Districts','Latitude','Longitude']
df_geo.head()
# Out:
#    Districts   Latitude   Longitude
# 0  Tsuen Wan  22.374630  114.115100
# 1    Sha Tin  22.383381  114.198517
# 2   Tuen Mun  22.396910  113.974411
# 3     Tai Po  22.445400  114.167709
# 4  Yuen Long  22.445570  114.022290

# %%
HK_df = pd.merge(df,
                 df_geo[['Districts','Latitude', 'Longitude']],
                 on='Districts')
HK_df
# Out:
#               Districts           Regions   Latitude   Longitude
# 0   Central and Western  Hong Kong Island  22.286660  114.154970
# 1               Eastern  Hong Kong Island  22.284031  114.224220
# 2              Southern  Hong Kong Island  22.247250  114.158836
# 3              Wan Chai  Hong Kong Island  22.279680  114.171692
# 4          Sham Shui Po           Kowloon  22.330700  114.162163
# 5          Kowloon City           Kowloon  22.328291  114.191490
# 6             Kwun Tong           Kowloon  22.313259  114.225807
# 7          Wong Tai Sin           Kowloon  22.342140  114.195831
# 8         Yau Tsim Mong           Kowloon  22.321320  114.172577
# 9               Islands   New Territories  22.289049  113.939430
# 10           Kwai Tsing   New Territories  22.354879  114.084007
# 11                North   New Territories  22.494711  114.138123
# 12             Sai Kung   New Territories  22.380680  114.265869
# 13              Sha Tin   New Territories  22.383381  114.198517
# 14               Tai Po   New Territories  22.445400  114.167709
# 15            Tsuen Wan   New Territories  22.374630  114.115100
# 16             Tuen Mun   New Territories  22.396910  113.974411
# 17            Yuen Long   New Territories  22.445570  114.022290

# %% [markdown]
# Now the data is ready
#
# # we now start analysing

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### Let's try the first district in our data

# %%
district_lat = HK_df.loc[0, 'Latitude']
district_long = HK_df.loc[0, 'Longitude']

district_name = HK_df.loc[0, 'Districts']

print('Latitude and longitude values of {} are {}, {}.'.format(district_name, 
                                                               district_lat, 
                                                               district_long))
# Out:
# Latitude and longitude values of Central and Western are 22.28666, 114.15496999999999.

# %% [markdown]
# ## Now, let's get the top 100 venues in radius of 500 meters.

# %%
LIMIT = 100
radius = 500

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    district_lat, 
    district_long, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=IWJBAAA3OUYS1Y0SAR2LRGDJLFPETWS5LMR1UMBTXS4A5PC5&client_secret=MBSNMK0YDLLZ3AALK5AIFBSO0B4KBE0AGMLASHRAAMVXQYW4&v=20180604&ll=22.28666,114.15496999999999&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e68f7adf7706a001b49a072'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Central District',
#   'headerFullLocation': 'Central District, Hong Kong',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 143,
#   'suggestedBounds': {'ne': {'lat': 22.291160004500007,
#     'lng': 114.15982422239976},
#    'sw': {'lat': 22.282159995499995, 'lng': 114.15011577760022}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588ccf964a52080da22e3',
#        'name': 'Four Seasons Hotel Hong Kong (香港四季酒店)',
#        'location': {'address': '8 Finance St',
#         'lat': 22.28655423619619,
#         'lng': 114.15692916188699,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28655423619619,
#           'lng': 114.15692916188699}],
#         'distance': 202,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['8 Finance St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588ccf964a52080da22e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fb216cee4b002c22861bda2',
#        'name': 'Galerie Perrotin',
#        'location': {'address': '17/F, 50 Connaught Road',
#         'lat': 22.28545518563427,
#         'lng': 114.15621532608225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28545518563427,
#           'lng': 114.15621532608225}],
#         'distance': 185,
#         'cc': 'HK',
#         'neighborhood': 'Central District',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['17/F, 50 Connaught Road', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fb216cee4b002c22861bda2-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cf09134c9af6dcb44ea937f',
#        'name': 'Central Indian Restaurant',
#        'location': {'address': 'Shop 101, 1/F, Cheungs Building, 1-3 Wing Lok St',
#         'lat': 22.285622,
#         'lng': 114.153839,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285622,
#           'lng': 114.153839}],
#         'distance': 164,
#         'cc': 'HK',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['Shop 101, 1/F, Cheungs Building, 1-3 Wing Lok St',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'shortName': 'Indian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cf09134c9af6dcb44ea937f-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c3d5ab87d002d7f52bcaf18',
#        'name': 'The Spa at Four Seasons',
#        'location': {'address': '5-7/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.286278830478437,
#         'lng': 114.15762268308455,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.286278830478437,
#           'lng': 114.15762268308455}],
#         'distance': 276,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['5-7/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'shortName': 'Spa',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c3d5ab87d002d7f52bcaf18-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b69049cf964a5200d972be3',
#        'name': '忠記粥品',
#        'location': {'address': "32-34 Gilman's Bazaar",
#         'lat': 22.285030611674244,
#         'lng': 114.15447436156464,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285030611674244,
#           'lng': 114.15447436156464}],
#         'distance': 188,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ["32-34 Gilman's Bazaar", '中西區', '香港']},
#        'categories': [{'id': '52af3a903cf9994f4e043bee',
#          'name': 'Chinese Breakfast Place',
#          'pluralName': 'Chinese Breakfast Places',
#          'shortName': 'Chinese Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b69049cf964a5200d972be3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fa66f0ae4b0fc2afbbfddf9',
#        'name': 'IFC Mall Ferry Pier Walkway',
#        'location': {'lat': 22.28709479519568,
#         'lng': 114.15767493500542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28709479519568,
#           'lng': 114.15767493500542}],
#         'distance': 282,
#         'cc': 'HK',
#         'country': '香港',
#         'formattedAddress': ['香港']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fa66f0ae4b0fc2afbbfddf9-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f17b44498ebbe799ed7113',
#        'name': 'Godenya',
#        'location': {'address': '182 Wellington St',
#         'crossStreet': 'at Kau U Fong',
#         'lat': 22.28467265865365,
#         'lng': 114.15319517201786,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28467265865365,
#           'lng': 114.15319517201786}],
#         'distance': 286,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '中区',
#         'country': '香港',
#         'formattedAddress': ['182 Wellington St (at Kau U Fong)', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f17b44498ebbe799ed7113-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5644840f498e2c069791ec6f',
#        'name': 'VEA Restaurant and Bar',
#        'location': {'address': '30/F 198 Wellington St',
#         'lat': 22.28489,
#         'lng': 114.152953,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28489,
#           'lng': 114.152953}],
#         'distance': 286,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['30/F 198 Wellington St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5644840f498e2c069791ec6f-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '533fff61498e424c5874d29e',
#        'name': 'Marks & Spencer Food',
#        'location': {'address': 'Shop 206, Shun Tak Centre',
#         'lat': 22.287795681111362,
#         'lng': 114.15299680066443,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.287795681111362,
#           'lng': 114.15299680066443}],
#         'distance': 239,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'state': 'Hong Kong',
#         'country': '香港',
#         'formattedAddress': ['Shop 206, Shun Tak Centre', 'Hong Kong', '香港']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-533fff61498e424c5874d29e-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5e1d9a368e5363000879bf87',
#        'name': 'Samsen (泰館)',
#        'location': {'address': 'G/F, 23 Jervois Street',
#         'lat': 22.285082050407347,
#         'lng': 114.15228568017483,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285082050407347,
#           'lng': 114.15228568017483}],
#         'distance': 327,
#         'cc': 'HK',
#         'neighborhood': 'Central District',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['G/F, 23 Jervois Street', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'shortName': 'Thai',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5e1d9a368e5363000879bf87-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588d9f964a520fddc22e3',
#        'name': 'Lung King Heen (龍景軒)',
#        'location': {'address': '4/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.28682460692335,
#         'lng': 114.15738642654397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28682460692335,
#           'lng': 114.15738642654397}],
#         'distance': 249,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['4/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#          'name': 'Cantonese Restaurant',
#          'pluralName': 'Cantonese Restaurants',
#          'shortName': 'Cantonese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588d9f964a520fddc22e3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a8fdb70f96b2c5099742dcb',
#        'name': 'Coco Espresso',
#        'location': {'address': '13-15 Jervois Street',
#         'lat': 22.285117083604856,
#         'lng': 114.15246596526333,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285117083604856,
#           'lng': 114.15246596526333}],
#         'distance': 309,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'country': '香港',
#         'formattedAddress': ['13-15 Jervois Street', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a8fdb70f96b2c5099742dcb-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee4ba912c5b5fc6cca0e056',
#        'name': 'Executive Club (行政貴賓廳)',
#        'location': {'address': '45/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.286816868657255,
#         'lng': 114.15670755717228,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.286816868657255,
#           'lng': 114.15670755717228}],
#         'distance': 179,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['45/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'shortName': 'Lounge',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee4ba912c5b5fc6cca0e056-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588d0f964a52048db22e3',
#        'name': 'Pool Terrace (池畔餐廳)',
#        'location': {'address': '6/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.28621842273582,
#         'lng': 114.15758292235269,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28621842273582,
#           'lng': 114.15758292235269}],
#         'distance': 273,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['6/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588d0f964a52048db22e3-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0903d2f964a520d81323e3',
#        'name': "city'super",
#        'location': {'address': 'Shop 1041-1049, ifc mall, 8 Finance St',
#         'lat': 22.2863191254814,
#         'lng': 114.15780586214832,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.2863191254814,
#           'lng': 114.15780586214832}],
#         'distance': 294,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop 1041-1049, ifc mall, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0903d2f964a520d81323e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b59a2f9f964a5202d9028e3',
#        'name': 'The Beer Bay',
#        'location': {'address': 'Shop K4, Central Pier No. 3, Man Kwong St',
#         'lat': 22.287795455088677,
#         'lng': 114.15754303008653,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.287795455088677,
#           'lng': 114.15754303008653}],
#         'distance': 293,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop K4, Central Pier No. 3, Man Kwong St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'shortName': 'Beer Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b59a2f9f964a5202d9028e3-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0b093c009a0f470f90eabf',
#        'name': 'The Lounge',
#        'location': {'address': 'Four Seasons Hotel, 8 Finance St',
#         'lat': 22.28685941516342,
#         'lng': 114.15680162212848,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28685941516342,
#           'lng': 114.15680162212848}],
#         'distance': 189,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Four Seasons Hotel, 8 Finance St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0b093c009a0f470f90eabf-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51262240e4b0a34a7c5f7c78',
#        'name': 'Ronin',
#        'location': {'address': '8 On Wo Ln',
#         'crossStreet': 'Kau U Fong',
#         'lat': 22.284525,
#         'lng': 114.15243,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.284525,
#           'lng': 114.15243}],
#         'distance': 353,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['8 On Wo Ln (Kau U Fong)', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51262240e4b0a34a7c5f7c78-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588d0f964a52049db22e3',
#        'name': 'Blue Bar',
#        'location': {'address': 'Lobby level, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.286816996687183,
#         'lng': 114.15746366701781,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.286816996687183,
#           'lng': 114.15746366701781}],
#         'distance': 257,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Lobby level, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1d5941735',
#          'name': 'Hotel Bar',
#          'pluralName': 'Hotel Bars',
#          'shortName': 'Hotel Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_bar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588d0f964a52049db22e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a702ff347f8766d3c3634a1',
#        'name': 'Mammy Pancake (媽咪雞蛋仔)',
#        'location': {'address': '32 Bonham Strand W',
#         'crossStreet': 'Hillier St. & Bonham Strand W',
#         'lat': 22.285684847935297,
#         'lng': 114.15184963265446,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285684847935297,
#           'lng': 114.15184963265446}],
#         'distance': 339,
#         'cc': 'HK',
#         'neighborhood': 'Central District',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['32 Bonham Strand W (Hillier St. & Bonham Strand W)',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1c7941735',
#          'name': 'Snack Place',
#          'pluralName': 'Snack Places',
#          'shortName': 'Snacks',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/snacks_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a702ff347f8766d3c3634a1-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54cddca3498ee7851d25af36',
#        'name': 'Table',
#        'location': {'address': '8/F, The Pemberton, 22-26 Bonham Strand East',
#         'crossStreet': 'at Man Wah Ln',
#         'lat': 22.28563362437341,
#         'lng': 114.15215361475725,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28563362437341,
#           'lng': 114.15215361475725}],
#         'distance': 311,
#         'cc': 'HK',
#         'neighborhood': 'Sheung Wan',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['8/F, The Pemberton, 22-26 Bonham Strand East (at Man Wah Ln)',
#          '香港']},
#        'categories': [{'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'shortName': 'Modern European',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54cddca3498ee7851d25af36-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfde72fc51fa1cd7992f32b',
#        'name': '001',
#        'location': {'address': 'Shop G1, LG/F, Welley Bldg, 97 Wellington St',
#         'lat': 22.283574289373693,
#         'lng': 114.15419899821195,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283574289373693,
#           'lng': 114.15419899821195}],
#         'distance': 352,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop G1, LG/F, Welley Bldg, 97 Wellington St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfde72fc51fa1cd7992f32b-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c63b42fedd320a1c912b029',
#        'name': 'Godiva',
#        'location': {'address': 'Shop 1029-1030, IFC Mall, 1 Harbour View St',
#         'lat': 22.28510108167692,
#         'lng': 114.15732228279757,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28510108167692,
#           'lng': 114.15732228279757}],
#         'distance': 298,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop 1029-1030, IFC Mall, 1 Harbour View St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c63b42fedd320a1c912b029-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5142ffc0e4b0654d30180d58',
#        'name': 'Caprice Bar',
#        'location': {'address': '6/F, Four Seasons Hong Kong, 8 Finance St',
#         'lat': 22.287115753775424,
#         'lng': 114.15708717957995,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.287115753775424,
#           'lng': 114.15708717957995}],
#         'distance': 223,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['6/F, Four Seasons Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5142ffc0e4b0654d30180d58-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51f78c00498e852dc483a48c',
#        'name': 'Pure Yoga',
#        'location': {'address': "2/F, Asia Standard Tower, 59-65 Queen's Rd C",
#         'lat': 22.283022433502484,
#         'lng': 114.15567435938205,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283022433502484,
#           'lng': 114.15567435938205}],
#         'distance': 411,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ["2/F, Asia Standard Tower, 59-65 Queen's Rd C",
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51f78c00498e852dc483a48c-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5395a064498e2faabd60df3c',
#        'name': 'Purple Tomato',
#        'location': {'address': '2 Jervois Street',
#         'lat': 22.28514054607155,
#         'lng': 114.15281937758814,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28514054607155,
#           'lng': 114.15281937758814}],
#         'distance': 278,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'state': 'Hong Kong',
#         'country': '香港',
#         'formattedAddress': ['2 Jervois Street', 'Hong Kong', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'shortName': 'Salad',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5395a064498e2faabd60df3c-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d83240498ea1a3fada5c7a',
#        'name': 'Sense99',
#        'location': {'address': '2/F, 99 Wellington St',
#         'lat': 22.284085001581126,
#         'lng': 114.15387609496894,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.284085001581126,
#           'lng': 114.15387609496894}],
#         'distance': 307,
#         'cc': 'HK',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['2/F, 99 Wellington St', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51d83240498ea1a3fada5c7a-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a1ec394ee628b656886da7d',
#        'name': 'Sushi Saito (鮨·齋藤)',
#        'location': {'address': 'Portion of Shop A, 45/F, Four Seasons Hotel',
#         'lat': 22.28666186232096,
#         'lng': 114.15675220388175,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28666186232096,
#           'lng': 114.15675220388175}],
#         'distance': 183,
#         'cc': 'HK',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['Portion of Shop A, 45/F, Four Seasons Hotel',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a1ec394ee628b656886da7d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51a1aa37498e1d8e28f14139',
#        'name': 'HK Brewcraft',
#        'location': {'address': '4/F, Kwok Lun Commercial House',
#         'crossStreet': '15 Cochrane Street',
#         'lat': 22.283352255860205,
#         'lng': 114.15473787260294,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283352255860205,
#           'lng': 114.15473787260294}],
#         'distance': 368,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['4/F, Kwok Lun Commercial House (15 Cochrane Street)',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '5370f356bcbc57f1066c94c2',
#          'name': 'Beer Store',
#          'pluralName': 'Beer Stores',
#          'shortName': 'Beer Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51a1aa37498e1d8e28f14139-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56c6ea5fcd1040365d3a6881',
#        'name': 'Le Quinze Vins',
#        'location': {'address': 'Gage St',
#         'lat': 22.283620304075235,
#         'lng': 114.15333219884772,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283620304075235,
#           'lng': 114.15333219884772}],
#         'distance': 378,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Gage St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56c6ea5fcd1040365d3a6881-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54843227498e6ba0cc8616c1',
#        'name': 'The Pier Bar',
#        'location': {'address': 'Pier Three',
#         'lat': 22.28779092049608,
#         'lng': 114.1574110136706,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28779092049608,
#           'lng': 114.1574110136706}],
#         'distance': 281,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Pier Three', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54843227498e6ba0cc8616c1-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b42db5af964a52081da25e3',
#        'name': 'Fuel Espresso',
#        'location': {'address': 'Shop 3023, 3/F, IFC Mall, 1 Harbour View St',
#         'lat': 22.28507494595841,
#         'lng': 114.15729744090731,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28507494595841,
#           'lng': 114.15729744090731}],
#         'distance': 297,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop 3023, 3/F, IFC Mall, 1 Harbour View St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b42db5af964a52081da25e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53c52196498ee5a63cb595e4',
#        'name': 'The Pottinger (石板街酒店)',
#        'location': {'address': "74 Queen's Rd C",
#         'crossStreet': '21 Stanley St',
#         'lat': 22.282996028522952,
#         'lng': 114.15541252715063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.282996028522952,
#           'lng': 114.15541252715063}],
#         'distance': 410,
#         'cc': 'HK',
#         'neighborhood': 'Central District, Hong Kong',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ["74 Queen's Rd C (21 Stanley St)", '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53c52196498ee5a63cb595e4-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588d0f964a52046db22e3',
#        'name': 'Caprice',
#        'location': {'address': '6/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#         'lat': 22.287157249649393,
#         'lng': 114.15697410103273,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.287157249649393,
#           'lng': 114.15697410103273}],
#         'distance': 213,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['6/F, Four Seasons Hotel Hong Kong, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588d0f964a52046db22e3-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9b212ef964a520e7f435e3',
#        'name': 'The Chairman (大班樓)',
#        'location': {'address': '18 Kau U Fong',
#         'lat': 22.284424286410612,
#         'lng': 114.15279951957879,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.284424286410612,
#           'lng': 114.15279951957879}],
#         'distance': 334,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['18 Kau U Fong', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9b212ef964a520e7f435e3-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5084ce2fe4b09e409da280ae',
#        'name': 'Sushi Shikon (志魂)',
#        'location': {'address': 'G/F, The Mercer, 29 Jervois St',
#         'crossStreet': 'at Mercer St',
#         'lat': 22.28514228385278,
#         'lng': 114.15199646004277,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28514228385278,
#           'lng': 114.15199646004277}],
#         'distance': 349,
#         'cc': 'HK',
#         'neighborhood': 'Sheung wan',
#         'city': 'Sheung Wan',
#         'state': 'Hong Kong',
#         'country': '香港',
#         'formattedAddress': ['G/F, The Mercer, 29 Jervois St (at Mercer St)',
#          'Hong Kong',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'shortName': 'Sushi',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5084ce2fe4b09e409da280ae-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0588def964a520b9dd22e3',
#        'name': 'ifc mall (國際金融中心商場)',
#        'location': {'address': '8 Finance St',
#         'lat': 22.2846131,
#         'lng': 114.158156172,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.2846131,
#           'lng': 114.158156172}],
#         'distance': 399,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['8 Finance St', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1fd941735',
#          'name': 'Shopping Mall',
#          'pluralName': 'Shopping Malls',
#          'shortName': 'Mall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0588def964a520b9dd22e3-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58ef2db7588e3652c868bb74',
#        'name': 'NOC Coffee',
#        'location': {'address': '18 Gough St',
#         'crossStreet': 'Hollywood Road',
#         'lat': 22.284121370127735,
#         'lng': 114.15260548771272,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.284121370127735,
#           'lng': 114.15260548771272}],
#         'distance': 373,
#         'cc': 'HK',
#         'neighborhood': 'Central District',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['18 Gough St (Hollywood Road)', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58ef2db7588e3652c868bb74-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e449bd6091a286cc7f84ac1',
#        'name': 'Shou Zen (尚善)',
#        'location': {'address': '7/F, The Pemberton, 22-26 Bonham Strand',
#         'lat': 22.285580481163755,
#         'lng': 114.15218760124932,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285580481163755,
#           'lng': 114.15218760124932}],
#         'distance': 310,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'country': '香港',
#         'formattedAddress': ['7/F, The Pemberton, 22-26 Bonham Strand', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '61041623'}},
#       'referralId': 'e-0-4e449bd6091a286cc7f84ac1-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1f2dd6f964a520b22424e3',
#        'name': 'Shui Kee (水記)',
#        'location': {'address': 'Stall 2, Gutzlaff St',
#         'lat': 22.283507353818667,
#         'lng': 114.15440917814173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283507353818667,
#           'lng': 114.15440917814173}],
#         'distance': 355,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Stall 2, Gutzlaff St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'shortName': 'Chinese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b1f2dd6f964a520b22424e3-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b0df819f964a5204e5323e3',
#        'name': 'Palace IFC (百老匯院線)',
#        'location': {'address': 'Shop 1058B, 1/F, ifc mall, 8 Finance St',
#         'lat': 22.285742434142808,
#         'lng': 114.1581680176365,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285742434142808,
#           'lng': 114.1581680176365}],
#         'distance': 344,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop 1058B, 1/F, ifc mall, 8 Finance St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d180941735',
#          'name': 'Multiplex',
#          'pluralName': 'Multiplexes',
#          'shortName': 'Cineplex',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/movietheater_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b0df819f964a5204e5323e3-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '589552aa561ded434dd868e2',
#        'name': 'Brass Spoon',
#        'location': {'address': 'G/F, 10 Pottinger St',
#         'lat': 22.2833287811399,
#         'lng': 114.15609290015186,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.2833287811399,
#           'lng': 114.15609290015186}],
#         'distance': 388,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['G/F, 10 Pottinger St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'shortName': 'Asian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-589552aa561ded434dd868e2-41'},
#      {'reasons': {'count': 0,
# ...
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54b7a887498efb30ffa4d47b-85'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f86ad32e4b05dd5645c7301',
#        'name': 'Quinary',
#        'location': {'address': '56-58 Hollywood Rd',
#         'lat': 22.282796205468646,
#         'lng': 114.15290284941022,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.282796205468646,
#           'lng': 114.15290284941022}],
#         'distance': 479,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['56-58 Hollywood Rd', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f86ad32e4b05dd5645c7301-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523866a8498ef04b80c6a44c',
#        'name': 'The Black Star',
#        'location': {'address': '81 Wing Lok St',
#         'lat': 22.286057798406972,
#         'lng': 114.15217758853142,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.286057798406972,
#           'lng': 114.15217758853142}],
#         'distance': 295,
#         'cc': 'HK',
#         'neighborhood': 'Sheung Wan',
#         'city': 'Sheung Wan',
#         'state': 'Hong Kong',
#         'country': '香港',
#         'formattedAddress': ['81 Wing Lok St', 'Hong Kong', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'shortName': 'Cocktail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523866a8498ef04b80c6a44c-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed70871be7b3567163a9b79',
#        'name': 'Yat Lok Restaurant (一樂燒鵝)',
#        'location': {'address': 'G/F, 34-38 Stanley St',
#         'lat': 22.28253600884452,
#         'lng': 114.15536735301605,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28253600884452,
#           'lng': 114.15536735301605}],
#         'distance': 460,
#         'cc': 'HK',
#         'neighborhood': 'Central District',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['G/F, 34-38 Stanley St', '中西區', '香港']},
#        'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#          'name': 'Cantonese Restaurant',
#          'pluralName': 'Cantonese Restaurants',
#          'shortName': 'Cantonese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed70871be7b3567163a9b79-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bce805bb6c49c74375f9791',
#        'name': 'Isola Bar & Grill',
#        'location': {'address': 'JCSuggested: Shop 2075, 2/F, IFC, 1 Harbour View St',
#         'lat': 22.285936490567035,
#         'lng': 114.1584827385327,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285936490567035,
#           'lng': 114.1584827385327}],
#         'distance': 370,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['JCSuggested: Shop 2075, 2/F, IFC, 1 Harbour View St',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'shortName': 'Italian',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bce805bb6c49c74375f9791-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '543f4415498ebd860ead98e7',
#        'name': 'Healthy Chicken',
#        'location': {'address': 'Shop A2, G/F, Khuan Ying Commercial Bldg, 85-89 Wellington St',
#         'lat': 22.283292113475127,
#         'lng': 114.15439761260227,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283292113475127,
#           'lng': 114.15439761260227}],
#         'distance': 379,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': 'Central',
#         'state': 'Western (中西區)',
#         'country': '香港',
#         'formattedAddress': ['Shop A2, G/F, Khuan Ying Commercial Bldg, 85-89 Wellington St',
#          'Western (中西區)',
#          '香港']},
#        'categories': [{'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'shortName': 'Fried Chicken',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '112553788'}},
#       'referralId': 'e-0-543f4415498ebd860ead98e7-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bf349996a31d13a228c942e',
#        'name': 'The Yoga Room',
#        'location': {'address': '104 Jervois Street',
#         'crossStreet': 'Xiu Ping Comm Bldg',
#         'lat': 22.285356397818255,
#         'lng': 114.15071786218947,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285356397818255,
#           'lng': 114.15071786218947}],
#         'distance': 461,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'country': '香港',
#         'formattedAddress': ['104 Jervois Street (Xiu Ping Comm Bldg)', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'shortName': 'Yoga Studio',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bf349996a31d13a228c942e-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b4c99fcf964a52046b726e3',
#        'name': 'Club 71',
#        'location': {'address': '67 Hollywood Rd',
#         'lat': 22.283495564226538,
#         'lng': 114.15299915547544,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.283495564226538,
#           'lng': 114.15299915547544}],
#         'distance': 406,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['67 Hollywood Rd', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d118941735',
#          'name': 'Dive Bar',
#          'pluralName': 'Dive Bars',
#          'shortName': 'Dive Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/divebar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b4c99fcf964a52046b726e3-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cf7d1a9ff0306002cd7ad6a',
#        'name': 'Duck & Waffle',
#        'location': {'address': 'Shop 1081, Podium Level 1, ifc Mall, 8 Finance Street',
#         'lat': 22.285339,
#         'lng': 114.158745,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.285339,
#           'lng': 114.158745}],
#         'distance': 415,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['Shop 1081, Podium Level 1, ifc Mall, 8 Finance Street',
#          '中西區',
#          '香港']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a05',
#          'name': 'English Restaurant',
#          'pluralName': 'English Restaurants',
#          'shortName': 'English',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cf7d1a9ff0306002cd7ad6a-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c628b54fa7bc928d9440e27',
#        'name': 'Roof Garden (天台花園)',
#        'location': {'address': '4/F, IFC Mall, 1 Harbour View St',
#         'lat': 22.2856323919116,
#         'lng': 114.15884592934457,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.2856323919116,
#           'lng': 114.15884592934457}],
#         'distance': 415,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['4/F, IFC Mall, 1 Harbour View St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d15a941735',
#          'name': 'Garden',
#          'pluralName': 'Gardens',
#          'shortName': 'Garden',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/garden_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c628b54fa7bc928d9440e27-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a0e7d1bbd400971f568b704',
#        'name': 'Zagin Soba (座銀)',
#        'location': {'address': '7 Gough St',
#         'crossStreet': 'Aberdeen St',
#         'lat': 22.284149950507825,
#         'lng': 114.15285152737924,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.284149950507825,
#           'lng': 114.15285152737924}],
#         'distance': 354,
#         'cc': 'HK',
#         'city': '香港',
#         'country': '香港',
#         'formattedAddress': ['7 Gough St (Aberdeen St)', '香港']},
#        'categories': [{'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'shortName': 'Ramen',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a0e7d1bbd400971f568b704-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '526fa78011d209b07e5e91bf',
#        'name': 'La Vache!',
#        'location': {'address': '48 Peel St',
#         'lat': 22.28266096638407,
#         'lng': 114.15274851968225,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28266096638407,
#           'lng': 114.15274851968225}],
#         'distance': 500,
#         'cc': 'HK',
#         'neighborhood': 'Central',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['48 Peel St', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-526fa78011d209b07e5e91bf-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '561e5f30498e8804764fee45',
#        'name': 'Tenkai (天海)',
#        'location': {'address': 'G/F, 17 Aberdeen St',
#         'lat': 22.28386,
#         'lng': 114.152785,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28386,
#           'lng': 114.152785}],
#         'distance': 384,
#         'cc': 'HK',
#         'city': '中区',
#         'country': '香港',
#         'formattedAddress': ['G/F, 17 Aberdeen St', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'shortName': 'Japanese',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-561e5f30498e8804764fee45-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be30eea99feb713e9fb81f6',
#        'name': '7-Eleven',
#        'location': {'address': '89-91 Wing Lok St',
#         'crossStreet': 'at Hillier St',
#         'lat': 22.28611629037614,
#         'lng': 114.15202058213427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28611629037614,
#           'lng': 114.15202058213427}],
#         'distance': 309,
#         'cc': 'HK',
#         'city': 'Sheung Wan',
#         'country': '香港',
#         'formattedAddress': ['89-91 Wing Lok St (at Hillier St)', '香港']},
#        'categories': [{'id': '4d954b0ea243a5684a65b473',
#          'name': 'Convenience Store',
#          'pluralName': 'Convenience Stores',
#          'shortName': 'Convenience Store',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be30eea99feb713e9fb81f6-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d1b188c5acb721ea7770bb2',
#        'name': 'La Cabane a Vin',
#        'location': {'address': 'B/F., 97 Hollywood Rd',
#         'lat': 22.28385378457264,
#         'lng': 114.15223186164249,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 22.28385378457264,
#           'lng': 114.15223186164249}],
#         'distance': 420,
#         'cc': 'HK',
#         'city': '中環',
#         'state': '中西區',
#         'country': '香港',
#         'formattedAddress': ['B/F., 97 Hollywood Rd', '中西區', '香港']},
#        'categories': [{'id': '4bf58dd8d48988d119951735',
#          'name': 'Wine Shop',
#          'pluralName': 'Wine Shops',
#          'shortName': 'Wine Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d1b188c5acb721ea7770bb2-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                                     name               categories        lat  \
# 0  Four Seasons Hotel Hong Kong (香港四季酒店)                    Hotel  22.286554
# 1                       Galerie Perrotin              Art Gallery  22.285455
# 2              Central Indian Restaurant        Indian Restaurant  22.285622
# 3                The Spa at Four Seasons                      Spa  22.286279
# 4                                   忠記粥品  Chinese Breakfast Place  22.285031
#
#           lng
# 0  114.156929
# 1  114.156215
# 2  114.153839
# 3  114.157623
# 4  114.154474

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# # Now Let's Explore Districts in Hong Kong

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Districts', 
                  'District Latitude', 
                  'District Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
HK_venues = getNearbyVenues(names = HK_df['Districts'],
                                   latitudes = HK_df['Latitude'],
                                   longitudes = HK_df['Longitude']
                                  )
# Out:
# Central and Western
# Eastern
# Southern
# Wan Chai
# Sham Shui Po
# Kowloon City
# Kwun Tong
# Wong Tai Sin
# Yau Tsim Mong
# Islands
# Kwai Tsing
# North
# Sai Kung
# Sha Tin
# Tai Po
# Tsuen Wan
# Tuen Mun
# Yuen Long

# %%
print(HK_venues.shape)
HK_venues.head()
# Out:
# (708, 7)
#              Districts  District Latitude  District Longitude  \
# 0  Central and Western           22.28666           114.15497
# 1  Central and Western           22.28666           114.15497
# 2  Central and Western           22.28666           114.15497
# 3  Central and Western           22.28666           114.15497
# 4  Central and Western           22.28666           114.15497
#
#                                    Venue  Venue Latitude  Venue Longitude  \
# 0  Four Seasons Hotel Hong Kong (香港四季酒店)       22.286554       114.156929
# 1                       Galerie Perrotin       22.285455       114.156215
# 2              Central Indian Restaurant       22.285622       114.153839
# 3                The Spa at Four Seasons       22.286279       114.157623
# 4                                   忠記粥品       22.285031       114.154474
#
#             Venue Category
# 0                    Hotel
# 1              Art Gallery
# 2        Indian Restaurant
# 3                      Spa
# 4  Chinese Breakfast Place

# %% [markdown]
# Let's check how many venues were returned for each district

# %%
HK_venues.groupby('Districts').count()
# Out:
#                      District Latitude  District Longitude  Venue  \
# Districts
# Central and Western                100                 100    100
# Eastern                             16                  16     16
# Islands                             69                  69     69
# Kowloon City                        67                  67     67
# Kwai Tsing                           4                   4      4
# Kwun Tong                           62                  62     62
# North                               10                  10     10
# Sai Kung                             5                   5      5
# Sha Tin                             21                  21     21
# Sham Shui Po                        48                  48     48
# Southern                            23                  23     23
# Tai Po                              32                  32     32
# Tsuen Wan                           52                  52     52
# Tuen Mun                            30                  30     30
# Wan Chai                            60                  60     60
# Wong Tai Sin                        16                  16     16
# Yau Tsim Mong                       70                  70     70
# Yuen Long                           23                  23     23
#
#                      Venue Latitude  Venue Longitude  Venue Category
# Districts
# Central and Western             100              100             100
# Eastern                          16               16              16
# Islands                          69               69              69
# Kowloon City                     67               67              67
# Kwai Tsing                        4                4               4
# Kwun Tong                        62               62              62
# North                            10               10              10
# Sai Kung                          5                5               5
# Sha Tin                          21               21              21
# Sham Shui Po                     48               48              48
# Southern                         23               23              23
# Tai Po                           32               32              32
# Tsuen Wan                        52               52              52
# Tuen Mun                         30               30              30
# Wan Chai                         60               60              60
# Wong Tai Sin                     16               16              16
# Yau Tsim Mong                    70               70              70
# Yuen Long                        23               23              23

# %% [markdown]
# Let's find out how many unique categories can be curated from all the returned venues

# %%
print('There are {} uniques categories.'.format(len(HK_venues['Venue Category'].unique())))
# Out:
# There are 157 uniques categories.

# %% [markdown]
# # Now Let's Analyze Each District

# %%
# one hot encoding
HK_onehot = pd.get_dummies(HK_venues[['Venue Category']], prefix="", prefix_sep="")
HK_onehot.insert(loc=0, column='Districts', value=HK_venues['Districts'] )
HK_onehot.shape
# Out:
# (708, 158)

# %% [markdown]
# Next, let's group rows by districts and by taking the mean of the frequency of occurrence of each category

# %%
HK_grouped = HK_onehot.groupby('Districts').mean().reset_index()
HK_grouped.head()
# Out:
#              Districts  Accessories Store  Airport Service  Arcade  \
# 0  Central and Western           0.000000             0.01     0.0
# 1              Eastern           0.000000             0.00     0.0
# 2              Islands           0.028986             0.00     0.0
# 3         Kowloon City           0.000000             0.00     0.0
# 4           Kwai Tsing           0.000000             0.00     0.0
#
#    Art Gallery  Arts & Crafts Store  Asian Restaurant  Astrologer  \
# 0         0.01                 0.01          0.010000         0.0
# 1         0.00                 0.00          0.000000         0.0
# 2         0.00                 0.00          0.000000         0.0
# 3         0.00                 0.00          0.029851         0.0
# 4         0.00                 0.00          0.000000         0.0
#
#    Athletics & Sports  BBQ Joint    Bakery   Bar  Basketball Court  Beer Bar  \
# 0                 0.0       0.02  0.010000  0.02               0.0       0.0
# 1                 0.0       0.00  0.000000  0.00               0.0       0.0
# 2                 0.0       0.00  0.014493  0.00               0.0       0.0
# 3                 0.0       0.00  0.029851  0.00               0.0       0.0
# 4                 0.0       0.00  0.000000  0.00               0.0       0.0
#
#    Beer Garden  Beer Store  Beijing Restaurant  Betting Shop    Bistro  \
# 0         0.01        0.01                 0.0           0.0  0.000000
# 1         0.00        0.00                 0.0           0.0  0.000000
# 2         0.00        0.00                 0.0           0.0  0.000000
# 3         0.00        0.00                 0.0           0.0  0.014925
# 4         0.00        0.00                 0.0           0.0  0.000000
#
#    Bookstore  Boutique  Bowling Alley  Breakfast Spot  Bubble Tea Shop  \
# 0   0.000000  0.000000            0.0        0.000000         0.000000
# 1   0.000000  0.000000            0.0        0.000000         0.000000
# 2   0.014493  0.014493            0.0        0.014493         0.028986
# 3   0.000000  0.000000            0.0        0.000000         0.000000
# 4   0.000000  0.000000            0.0        0.000000         0.000000
#
#      Buffet  Building  Burger Joint  Bus Station  Bus Stop  Cable Car  \
# 0  0.000000       0.0           0.0     0.000000  0.000000   0.000000
# 1  0.000000       0.0           0.0     0.000000  0.000000   0.000000
# 2  0.014493       0.0           0.0     0.014493  0.014493   0.014493
# 3  0.000000       0.0           0.0     0.000000  0.000000   0.000000
# 4  0.000000       0.0           0.0     0.250000  0.000000   0.000000
#
#        Café  Cantonese Restaurant  Cha Chaan Teng  Chinese Breakfast Place  \
# 0  0.020000              0.020000        0.000000                 0.010000
# 1  0.000000              0.062500        0.062500                 0.000000
# 2  0.028986              0.014493        0.028986                 0.000000
# 3  0.059701              0.029851        0.044776                 0.014925
# 4  0.000000              0.000000        0.000000                 0.000000
#
#    Chinese Restaurant  Chocolate Shop  Climbing Gym  Clothing Store  \
# 0            0.060000            0.01           0.0        0.000000
# 1            0.312500            0.00           0.0        0.000000
# 2            0.028986            0.00           0.0        0.057971
# 3            0.074627            0.00           0.0        0.000000
# 4            0.000000            0.00           0.0        0.000000
#
#    Cocktail Bar  Coffee Shop  Convenience Store  Cosmetics Shop  Creperie  \
# 0          0.04     0.060000           0.010000        0.010000      0.01
# 1          0.00     0.062500           0.000000        0.000000      0.00
# 2          0.00     0.043478           0.014493        0.014493      0.00
# 3          0.00     0.059701           0.000000        0.000000      0.00
# 4          0.00     0.000000           0.000000        0.000000      0.00
#
#    Cupcake Shop  Deli / Bodega  Department Store  Design Studio  Dessert Shop  \
# 0           0.0            0.0              0.01            0.0      0.000000
# 1           0.0            0.0              0.00            0.0      0.000000
# 2           0.0            0.0              0.00            0.0      0.000000
# 3           0.0            0.0              0.00            0.0      0.149254
# 4           0.0            0.0              0.00            0.0      0.000000
#
#    Dim Sum Restaurant     Diner  Dive Bar  Donburi Restaurant  \
# 0            0.010000  0.000000      0.01                 0.0
# 1            0.000000  0.000000      0.00                 0.0
# 2            0.000000  0.014493      0.00                 0.0
# 3            0.014925  0.000000      0.00                 0.0
# 4            0.000000  0.000000      0.00                 0.0
#
#    Dumpling Restaurant  Electronics Store  English Restaurant  \
# 0                 0.01           0.010000                0.01
# 1                 0.00           0.000000                0.00
# 2                 0.00           0.014493                0.00
# 3                 0.00           0.000000                0.00
# 4                 0.00           0.000000                0.00
#
#    Fast Food Restaurant  Flea Market  Flower Shop  Food Court  \
# 0              0.000000          0.0          0.0         0.0
# 1              0.000000          0.0          0.0         0.0
# 2              0.000000          0.0          0.0         0.0
# 3              0.044776          0.0          0.0         0.0
# 4              0.000000          0.0          0.0         0.0
#
#    French Restaurant  Fried Chicken Joint  Furniture / Home Store  Garden  \
# 0             0.0400                 0.01                0.000000    0.01
# 1             0.0625                 0.00                0.000000    0.00
# 2             0.0000                 0.00                0.014493    0.00
# 3             0.0000                 0.00                0.000000    0.00
# 4             0.0000                 0.00                0.000000    0.00
#
#    Gastropub  Gourmet Shop  Grocery Store   Gym  Gym / Fitness Center  \
# 0        0.0           0.0       0.000000  0.01              0.010000
# 1        0.0           0.0       0.000000  0.00              0.000000
# 2        0.0           0.0       0.014493  0.00              0.014493
# 3        0.0           0.0       0.000000  0.00              0.000000
# 4        0.0           0.0       0.000000  0.00              0.000000
#
#    Halal Restaurant  Harbor / Marina  History Museum  Hobby Shop  \
# 0          0.000000           0.0000             0.0         0.0
# 1          0.000000           0.0625             0.0         0.0
# 2          0.000000           0.0000             0.0         0.0
# 3          0.029851           0.0000             0.0         0.0
# 4          0.000000           0.0000             0.0         0.0
#
#    Hong Kong Restaurant  Hostel  Hot Dog Joint     Hotel  Hotel Bar  \
# 0              0.010000     0.0            0.0  0.030000   0.020000
# 1              0.062500     0.0            0.0  0.000000   0.000000
# 2              0.014493     0.0            0.0  0.014493   0.014493
# 3              0.000000     0.0            0.0  0.029851   0.000000
# 4              0.000000     0.0            0.0  0.000000   0.000000
#
#    Hotpot Restaurant  Hunan Restaurant  Ice Cream Shop  Indian Restaurant  \
# 0           0.000000          0.000000            0.01             0.0100
# 1           0.000000          0.000000            0.00             0.0625
# 2           0.000000          0.000000            0.00             0.0000
# 3           0.029851          0.014925            0.00             0.0000
# 4           0.000000          0.000000            0.00             0.0000
#
#    Indonesian Restaurant  Italian Restaurant  Japanese Restaurant  \
# 0                    0.0            0.010000             0.050000
# 1                    0.0            0.000000             0.062500
# 2                    0.0            0.014493             0.014493
# 3                    0.0            0.000000             0.014925
# 4                    0.0            0.000000             0.000000
#
#    Jewelry Store  Jiangsu Restaurant  Karaoke Bar  Korean Restaurant  \
# 0       0.000000                 0.0          0.0           0.010000
# 1       0.000000                 0.0          0.0           0.000000
# 2       0.014493                 0.0          0.0           0.028986
# 3       0.000000                 0.0          0.0           0.000000
# 4       0.000000                 0.0          0.0           0.000000
#
#    Lebanese Restaurant  Light Rail Station  Lingerie Store  Lounge  \
# 0                  0.0                 0.0        0.000000    0.01
# 1                  0.0                 0.0        0.000000    0.00
# 2                  0.0                 0.0        0.014493    0.00
# 3                  0.0                 0.0        0.000000    0.00
# 4                  0.0                 0.0        0.000000    0.00
#
#    Malay Restaurant    Market  Martial Arts Dojo  Massage Studio  \
# 0               0.0  0.000000               0.01            0.02
# 1               0.0  0.000000               0.00            0.00
# 2               0.0  0.014493               0.00            0.00
# 3               0.0  0.014925               0.00            0.00
# 4               0.0  0.000000               0.00            0.00
#
#    Mediterranean Restaurant  Middle Eastern Restaurant  Mobile Phone Shop  \
# 0                  0.010000                       0.01               0.00
# 1                  0.000000                       0.00               0.00
# 2                  0.014493                       0.00               0.00
# 3                  0.000000                       0.00               0.00
# 4                  0.000000                       0.00               0.25
#
#    Modern European Restaurant  Movie Theater  Multiplex  \
# 0                        0.02            0.0       0.01
# 1                        0.00            0.0       0.00
# 2                        0.00            0.0       0.00
# 3                        0.00            0.0       0.00
# 4                        0.00            0.0       0.00
#
#    New American Restaurant  Noodle House  Outdoor Supply Store  Outlet Store  \
# 0                 0.000000      0.010000                   0.0      0.000000
# 1                 0.000000      0.000000                   0.0      0.000000
# 2                 0.014493      0.014493                   0.0      0.014493
# 3                 0.000000      0.029851                   0.0      0.000000
# 4                 0.000000      0.000000                   0.0      0.000000
#
#    Paper / Office Supplies Store      Park  Pastry Shop  \
# 0                            0.0  0.000000     0.000000
# 1                            0.0  0.125000     0.000000
# 2                            0.0  0.000000     0.000000
# 3                            0.0  0.014925     0.014925
# 4                            0.0  0.000000     0.000000
#
#    Performing Arts Venue  Perfume Shop  Peruvian Restaurant  Pharmacy  \
# 0                    0.0           0.0                 0.01  0.000000
# 1                    0.0           0.0                 0.00  0.000000
# 2                    0.0           0.0                 0.00  0.028986
# 3                    0.0           0.0                 0.00  0.000000
# 4                    0.0           0.0                 0.00  0.000000
#
#    Pizza Place  Platform  Playground  Plaza  Pub  Ramen Restaurant  \
# 0          0.0  0.000000         0.0    0.0  0.0          0.010000
# 1          0.0  0.000000         0.0    0.0  0.0          0.000000
# 2          0.0  0.014493         0.0    0.0  0.0          0.014493
# 3          0.0  0.000000         0.0    0.0  0.0          0.000000
# 4          0.0  0.000000         0.0    0.0  0.0          0.000000
#
#    Restaurant  River  Salad Place  Salon / Barbershop  Sandwich Place  \
# 0    0.000000    0.0         0.02                0.01        0.000000
# 1    0.062500    0.0         0.00                0.00        0.000000
# 2    0.000000    0.0         0.00                0.00        0.014493
# 3    0.014925    0.0         0.00                0.00        0.000000
# 4    0.000000    0.0         0.00                0.00        0.000000
#
#    Scenic Lookout  Seafood Restaurant  Shanghai Restaurant  Shoe Store  \
# 0            0.01            0.000000                  0.0    0.000000
# 1            0.00            0.000000                  0.0    0.000000
# 2            0.00            0.000000                  0.0    0.014493
# 3            0.00            0.029851                  0.0    0.000000
# 4            0.25            0.000000                  0.0    0.000000
#
#    Shop & Service  Shopping Mall  Shopping Plaza  Snack Place  Soccer Field  \
# 0        0.000000       0.010000             0.0         0.02           0.0
# 1        0.000000       0.000000             0.0         0.00           0.0
# 2        0.014493       0.014493             0.0         0.00           0.0
# 3        0.000000       0.000000             0.0         0.00           0.0
# 4        0.000000       0.000000             0.0         0.00           0.0
#
#    Soup Place   Spa  Spanish Restaurant  Speakeasy  Sporting Goods Shop  \
# 0    0.000000  0.01                 0.0       0.01             0.000000
# 1    0.000000  0.00                 0.0       0.00             0.000000
# 2    0.014493  0.00                 0.0       0.00             0.043478
# 3    0.000000  0.00                 0.0       0.00             0.000000
# 4    0.000000  0.00                 0.0       0.00             0.000000
#
#    Sports Bar  Stadium  Steakhouse  Supermarket  Sushi Restaurant  \
# 0    0.000000      0.0         0.0     0.020000          0.020000
# 1    0.000000      0.0         0.0     0.000000          0.000000
# 2    0.014493      0.0         0.0     0.014493          0.043478
# 3    0.000000      0.0         0.0     0.000000          0.000000
# 4    0.000000      0.0         0.0     0.000000          0.000000
#
#    Szechuan Restaurant  Taiwanese Restaurant  Tapas Restaurant  Temple  \
# 0                  0.0              0.000000               0.0     0.0
# 1                  0.0              0.000000               0.0     0.0
# 2                  0.0              0.014493               0.0     0.0
# 3                  0.0              0.000000               0.0     0.0
# 4                  0.0              0.000000               0.0     0.0
#
#    Thai Restaurant  Theater  Trail  Train Station  Udon Restaurant  \
# 0         0.010000      0.0   0.00            0.0              0.0
# 1         0.000000      0.0   0.00            0.0              0.0
# 2         0.014493      0.0   0.00            0.0              0.0
# 3         0.179104      0.0   0.00            0.0              0.0
# 4         0.000000      0.0   0.25            0.0              0.0
#
#    Vegetarian / Vegan Restaurant  Vietnamese Restaurant  Wine Bar  Wine Shop  \
# 0                           0.01               0.000000      0.04       0.02
# 1                           0.00               0.000000      0.00       0.00
# 2                           0.00               0.014493      0.00       0.00
# 3                           0.00               0.014925      0.00       0.00
# 4                           0.00               0.000000      0.00       0.00
#
#    Women's Store  Yoga Studio
# 0       0.000000     0.020000
# 1       0.000000     0.000000
# 2       0.014493     0.014493
# 3       0.000000     0.000000
# 4       0.000000     0.000000

# %% [markdown]
# Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for dist in HK_grouped['Districts']:
    print("----"+dist+"----")
    temp = HK_grouped[HK_grouped['Districts'] == dist].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Central and Western----
#                  venue  freq
# 0          Coffee Shop  0.06
# 1   Chinese Restaurant  0.06
# 2  Japanese Restaurant  0.05
# 3    French Restaurant  0.04
# 4             Wine Bar  0.04
#
#
# ----Eastern----
#                   venue  freq
# 0    Chinese Restaurant  0.31
# 1                  Park  0.12
# 2   Japanese Restaurant  0.06
# 3  Hong Kong Restaurant  0.06
# 4           Coffee Shop  0.06
#
#
# ----Islands----
#                  venue  freq
# 0       Clothing Store  0.06
# 1          Coffee Shop  0.04
# 2     Sushi Restaurant  0.04
# 3  Sporting Goods Shop  0.04
# 4    Accessories Store  0.03
#
#
# ----Kowloon City----
#                 venue  freq
# 0     Thai Restaurant  0.18
# 1        Dessert Shop  0.15
# 2  Chinese Restaurant  0.07
# 3                Café  0.06
# 4         Coffee Shop  0.06
#
#
# ----Kwai Tsing----
#                venue  freq
# 0  Mobile Phone Shop  0.25
# 1        Bus Station  0.25
# 2     Scenic Lookout  0.25
# 3              Trail  0.25
# 4  Accessories Store  0.00
#
#
# ----Kwun Tong----
#                   venue  freq
# 0    Chinese Restaurant  0.11
# 1           Coffee Shop  0.08
# 2                  Café  0.06
# 3  Cantonese Restaurant  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----North----
#                   venue  freq
# 0  Fast Food Restaurant   0.2
# 1         Shopping Mall   0.1
# 2             Multiplex   0.1
# 3          Dessert Shop   0.1
# 4     Convenience Store   0.1
#
#
# ----Sai Kung----
#                 venue  freq
# 0       Bowling Alley   0.2
# 1         Coffee Shop   0.2
# 2       Grocery Store   0.2
# 3  Athletics & Sports   0.2
# 4         Pizza Place   0.2
#
#
# ----Sha Tin----
#                 venue  freq
# 0  Chinese Restaurant  0.19
# 1                Park  0.10
# 2            Bus Stop  0.05
# 3        Betting Shop  0.05
# 4             Stadium  0.05
#
#
# ----Sham Shui Po----
#                   venue  freq
# 0          Noodle House  0.17
# 1    Chinese Restaurant  0.10
# 2          Dessert Shop  0.08
# 3  Fast Food Restaurant  0.04
# 4         Shopping Mall  0.04
#
#
# ----Southern----
#                   venue  freq
# 0      Sushi Restaurant  0.09
# 1  Fast Food Restaurant  0.09
# 2        Cha Chaan Teng  0.09
# 3         Jewelry Store  0.04
# 4                 Plaza  0.04
#
#
# ----Tai Po----
#                   venue  freq
# 0    Chinese Restaurant  0.12
# 1        Cha Chaan Teng  0.09
# 2          Noodle House  0.09
# 3  Fast Food Restaurant  0.09
# 4  Cantonese Restaurant  0.06
#
#
# ----Tsuen Wan----
#                   venue  freq
# 0         Shopping Mall  0.12
# 1          Dessert Shop  0.10
# 2  Fast Food Restaurant  0.08
# 3          Noodle House  0.06
# 4  Cantonese Restaurant  0.06
#
#
# ----Tuen Mun----
#                 venue  freq
# 0           Multiplex  0.10
# 1         Coffee Shop  0.10
# 2  Light Rail Station  0.10
# 3        Dessert Shop  0.07
# 4       Shopping Mall  0.07
#
#
# ----Wan Chai----
#                  venue  freq
# 0                 Café  0.07
# 1  Japanese Restaurant  0.07
# 2          Coffee Shop  0.05
# 3   Chinese Restaurant  0.05
# 4                Hotel  0.05
#
#
# ----Wong Tai Sin----
#                   venue  freq
# 0  Fast Food Restaurant  0.19
# 1        Cha Chaan Teng  0.12
# 2           Coffee Shop  0.12
# 3   Szechuan Restaurant  0.06
# 4    Donburi Restaurant  0.06
#
#
# ----Yau Tsim Mong----
#                 venue  freq
# 0        Noodle House  0.06
# 1         Coffee Shop  0.06
# 2  Chinese Restaurant  0.06
# 3      Cha Chaan Teng  0.06
# 4        Dessert Shop  0.04
#
#
# ----Yuen Long----
#                   venue  freq
# 0          Dessert Shop  0.13
# 1           Coffee Shop  0.09
# 2  Cantonese Restaurant  0.09
# 3                  Café  0.09
# 4    Athletics & Sports  0.09

# %% [markdown]
# Let's put that into a pandas dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Districts']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
dist_venues_sorted = pd.DataFrame(columns=columns)
dist_venues_sorted['Districts'] = HK_grouped['Districts']

for ind in np.arange(HK_grouped.shape[0]):
    dist_venues_sorted.iloc[ind, 1:] = return_most_common_venues(HK_grouped.iloc[ind, :], num_top_venues)

dist_venues_sorted.head()
# Out:
#              Districts 1st Most Common Venue 2nd Most Common Venue  \
# 0  Central and Western           Coffee Shop    Chinese Restaurant
# 1              Eastern    Chinese Restaurant                  Park
# 2              Islands        Clothing Store   Sporting Goods Shop
# 3         Kowloon City       Thai Restaurant          Dessert Shop
# 4           Kwai Tsing     Mobile Phone Shop           Bus Station
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Restaurant              Wine Bar     French Restaurant
# 1           Coffee Shop  Cantonese Restaurant     Indian Restaurant
# 2           Coffee Shop      Sushi Restaurant                  Café
# 3    Chinese Restaurant                  Café           Coffee Shop
# 4                 Trail        Scenic Lookout              Dive Bar
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0          Cocktail Bar                 Hotel           Yoga Studio
# 1  Hong Kong Restaurant   Japanese Restaurant            Restaurant
# 2     Korean Restaurant    Chinese Restaurant        Cha Chaan Teng
# 3  Fast Food Restaurant        Cha Chaan Teng          Noodle House
# 4           Flea Market  Fast Food Restaurant    English Restaurant
#
#   9th Most Common Venue      10th Most Common Venue
# 0      Sushi Restaurant  Modern European Restaurant
# 1     French Restaurant             Harbor / Marina
# 2     Accessories Store                    Pharmacy
# 3  Cantonese Restaurant                      Bakery
# 4     Electronics Store         Dumpling Restaurant

# %% [markdown]
# # Now Let's Cluster Districts

# %%
# set number of clusters
kclusters = 5

HK_grouped_clustering = HK_grouped.drop('Districts', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(HK_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([4, 3, 4, 0, 1, 4, 0, 2, 3, 4], dtype=int32)

# %% [markdown]
# Let's create a new dataframe that includes the cluster as well as the top 10 venues for each district

# %%
# add clustering labels
dist_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

HK_merged = HK_df

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
HK_merged = HK_merged.join(dist_venues_sorted.set_index('Districts'), on='Districts')

HK_merged.head()
# Out:
#              Districts           Regions   Latitude   Longitude  \
# 0  Central and Western  Hong Kong Island  22.286660  114.154970
# 1              Eastern  Hong Kong Island  22.284031  114.224220
# 2             Southern  Hong Kong Island  22.247250  114.158836
# 3             Wan Chai  Hong Kong Island  22.279680  114.171692
# 4         Sham Shui Po           Kowloon  22.330700  114.162163
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               4           Coffee Shop    Chinese Restaurant
# 1               3    Chinese Restaurant                  Park
# 2               0  Fast Food Restaurant        Cha Chaan Teng
# 3               4   Japanese Restaurant                  Café
# 4               4          Noodle House    Chinese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0   Japanese Restaurant              Wine Bar     French Restaurant
# 1           Coffee Shop  Cantonese Restaurant     Indian Restaurant
# 2      Sushi Restaurant                Market          Dessert Shop
# 3                 Hotel           Coffee Shop    Chinese Restaurant
# 4          Dessert Shop           Snack Place    Italian Restaurant
#
#     6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0            Cocktail Bar                 Hotel           Yoga Studio
# 1    Hong Kong Restaurant   Japanese Restaurant            Restaurant
# 2  Furniture / Home Store          Noodle House                 River
# 3         Thai Restaurant    Spanish Restaurant  Hong Kong Restaurant
# 4    Hong Kong Restaurant         Shopping Mall  Fast Food Restaurant
#
#        9th Most Common Venue      10th Most Common Venue
# 0           Sushi Restaurant  Modern European Restaurant
# 1          French Restaurant             Harbor / Marina
# 2         Seafood Restaurant          Chinese Restaurant
# 3  Middle Eastern Restaurant              Clothing Store
# 4        Japanese Restaurant                      Market

# %%
dist_venues_sorted.head()
# Out:
#    Cluster Labels            Districts 1st Most Common Venue  \
# 0               4  Central and Western           Coffee Shop
# 1               3              Eastern    Chinese Restaurant
# 2               4              Islands        Clothing Store
# 3               0         Kowloon City       Thai Restaurant
# 4               1           Kwai Tsing     Mobile Phone Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0    Chinese Restaurant   Japanese Restaurant              Wine Bar
# 1                  Park           Coffee Shop  Cantonese Restaurant
# 2   Sporting Goods Shop           Coffee Shop      Sushi Restaurant
# 3          Dessert Shop    Chinese Restaurant                  Café
# 4           Bus Station                 Trail        Scenic Lookout
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0     French Restaurant          Cocktail Bar                 Hotel
# 1     Indian Restaurant  Hong Kong Restaurant   Japanese Restaurant
# 2                  Café     Korean Restaurant    Chinese Restaurant
# 3           Coffee Shop  Fast Food Restaurant        Cha Chaan Teng
# 4              Dive Bar           Flea Market  Fast Food Restaurant
#
#   8th Most Common Venue 9th Most Common Venue      10th Most Common Venue
# 0           Yoga Studio      Sushi Restaurant  Modern European Restaurant
# 1            Restaurant     French Restaurant             Harbor / Marina
# 2        Cha Chaan Teng     Accessories Store                    Pharmacy
# 3          Noodle House  Cantonese Restaurant                      Bakery
# 4    English Restaurant     Electronics Store         Dumpling Restaurant

# %% [markdown]
# Finally, let's visualize the resulting clusters

# %%
latitude = 22.28552
longitude = 114.15769
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(HK_merged['Latitude'], HK_merged['Longitude'], HK_merged['Districts'], HK_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Now Let's Examine Clusters

# %% [markdown]
# Elimination of Coffee Shop and Café place categories because of avoiding competition with other coffee shops.

# %%
One = dist_venues_sorted[dist_venues_sorted["1st Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
two = One[One["2nd Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
three =two[two["3rd Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
four = three[three["4th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
five = four[four["5th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
six = five[five["6th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
seven = six[six["7th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
eight = seven[seven["8th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
nine = eight[eight["9th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
Location_Recomendation = nine[nine["10th Most Common Venue"].apply(lambda x:x not in ['Coffee Shop','Café'])]
Location_Recomendation
# Out:
#     Cluster Labels     Districts 1st Most Common Venue 2nd Most Common Venue  \
# 4                1    Kwai Tsing     Mobile Phone Shop           Bus Station
# 8                3       Sha Tin    Chinese Restaurant                  Park
# 9                4  Sham Shui Po          Noodle House    Chinese Restaurant
# 10               0      Southern  Fast Food Restaurant        Cha Chaan Teng
# 11               0        Tai Po    Chinese Restaurant  Fast Food Restaurant
#
#    3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 4                  Trail           Scenic Lookout              Dive Bar
# 8      Convenience Store  Chinese Breakfast Place    Seafood Restaurant
# 9           Dessert Shop              Snack Place    Italian Restaurant
# 10      Sushi Restaurant                   Market          Dessert Shop
# 11        Cha Chaan Teng             Noodle House  Cantonese Restaurant
#
#      6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4              Flea Market  Fast Food Restaurant    English Restaurant
# 8             Betting Shop              Bus Stop    Dim Sum Restaurant
# 9     Hong Kong Restaurant         Shopping Mall  Fast Food Restaurant
# 10  Furniture / Home Store          Noodle House                 River
# 11                   Plaza          Dessert Shop           Bus Station
#
#    9th Most Common Venue 10th Most Common Venue
# 4      Electronics Store    Dumpling Restaurant
# 8                Stadium   Cantonese Restaurant
# 9    Japanese Restaurant                 Market
# 10    Seafood Restaurant     Chinese Restaurant
# 11       Bubble Tea Shop     Donburi Restaurant

# %% [markdown]
# ## Cluster 1

# %%
Location_Recomendation.loc[Location_Recomendation['Cluster Labels'] == 0]
# Out:
#     Cluster Labels Districts 1st Most Common Venue 2nd Most Common Venue  \
# 10               0  Southern  Fast Food Restaurant        Cha Chaan Teng
# 11               0    Tai Po    Chinese Restaurant  Fast Food Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 10      Sushi Restaurant                Market          Dessert Shop
# 11        Cha Chaan Teng          Noodle House  Cantonese Restaurant
#
#      6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 10  Furniture / Home Store          Noodle House                 River
# 11                   Plaza          Dessert Shop           Bus Station
#
#    9th Most Common Venue 10th Most Common Venue
# 10    Seafood Restaurant     Chinese Restaurant
# 11       Bubble Tea Shop     Donburi Restaurant

# %% [markdown]
# ## Cluster 2

# %%
Location_Recomendation.loc[Location_Recomendation['Cluster Labels'] == 1]
# Out:
#    Cluster Labels   Districts 1st Most Common Venue 2nd Most Common Venue  \
# 4               1  Kwai Tsing     Mobile Phone Shop           Bus Station
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 4                 Trail        Scenic Lookout              Dive Bar
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 4           Flea Market  Fast Food Restaurant    English Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 4     Electronics Store    Dumpling Restaurant

# %% [markdown]
# ## Cluster 3

# %%
Location_Recomendation.loc[Location_Recomendation['Cluster Labels'] == 2]
# Out:
# Empty DataFrame
# Columns: [Cluster Labels, Districts, 1st Most Common Venue, 2nd Most Common Venue, 3rd Most Common Venue, 4th Most Common Venue, 5th Most Common Venue, 6th Most Common Venue, 7th Most Common Venue, 8th Most Common Venue, 9th Most Common Venue, 10th Most Common Venue]
# Index: []

# %% [markdown]
# ## Cluster 4

# %%
Location_Recomendation.loc[Location_Recomendation['Cluster Labels'] == 3]
# Out:
#    Cluster Labels Districts 1st Most Common Venue 2nd Most Common Venue  \
# 8               3   Sha Tin    Chinese Restaurant                  Park
#
#   3rd Most Common Venue    4th Most Common Venue 5th Most Common Venue  \
# 8     Convenience Store  Chinese Breakfast Place    Seafood Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 8          Betting Shop              Bus Stop    Dim Sum Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 8               Stadium   Cantonese Restaurant

# %% [markdown]
# ## Cluster 5

# %%
Location_Recomendation.loc[Location_Recomendation['Cluster Labels'] == 4]
# Out:
#    Cluster Labels     Districts 1st Most Common Venue 2nd Most Common Venue  \
# 9               4  Sham Shui Po          Noodle House    Chinese Restaurant
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 9          Dessert Shop           Snack Place    Italian Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 9  Hong Kong Restaurant         Shopping Mall  Fast Food Restaurant
#
#   9th Most Common Venue 10th Most Common Venue
# 9   Japanese Restaurant                 Market

# %% [markdown]
# # Result and Discussion

# %% [markdown]
# The purpose of this project is to help people or coffee shop owners who want to open a new shop in an area by comparing the number of coffee shops in the area. From the result, we see that there are actually a large competition in Hong Kong, we see that out of the 18 districts in Hong Kong, we only have 5 districts where coffee shop is not in the top 10 common venue. Therefore, running a coffee shop in Hong Kong now may not be the best option. In case you really want to run a coffee shop, area in Cluster 4 may be the best option you have as there are some indirect competition in the area of other Cluster, like Dessert Shop, Bubble Tea Shop etc.

# %% [markdown]
# # Conclusion

# %% [markdown]
# This project helps one get a better understanding of the environment in relation to the most suitable place to open coffee shops. The future of this project includes considering other factors such as the cost of renting a place, the price of land to open a new coffee shop or even the work and salaries of each person in the area to be able to more accurately determine the price of coffee to be sold.
